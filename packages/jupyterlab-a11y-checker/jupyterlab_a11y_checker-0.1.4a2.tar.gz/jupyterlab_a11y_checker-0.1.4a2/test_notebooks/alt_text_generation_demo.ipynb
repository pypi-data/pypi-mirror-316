# %% [markdown]
# Image 1 is embedded with HTML code. Alt tag is not present.
#
# <img alt="The image captures the iconic Golden Gate Bridge, a renowned landmark in San Francisco, California. The bridge is illuminated against the backdrop of the setting sun, casting an enchanting glow over its length. The perspective from a distance allows for the full view of the structure, with the ocean visible on one side and a rocky shore with vegetation on the other. In the foreground, the beach provides a natural boundary between the land and water. The overall scene is picturesque, showcasing the natural beauty of the area alongside its man-made marvels. (This is an alt-text generated by LLaVA, a large language model)." src="https://upload.wikimedia.org/wikipedia/commons/9/93/GoldenGateBridge_BakerBeach_MC.jpg">
# </img>

# %% [markdown]
# Image 2 is embedded with HTML code. Alt tag comes before src tag.
#
# <img alt="" src="https://upload.wikimedia.org/wikipedia/commons/3/33/Berkeley_cityscape_at_sunrise.jpg"></img>

# %% [markdown]
# Image 3 is embedded with HTML code. Alt tag comes after src tag.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/7f/European_Brown_Bear.jpg" alt="">
# </img>

# %% [markdown]
# Image 4 is embedded with HTML code. Alt tag is located in between tags.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/2d/Oski_at_Cal_Day_2010_2.JPG" alt="Oski walking down the stairs." width="60"></img>

# %% [markdown]
# Image 5 is embedded with Markdown. Alt tag is not present.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/7/79/Doe_Library_-_detail_West.jpg)
