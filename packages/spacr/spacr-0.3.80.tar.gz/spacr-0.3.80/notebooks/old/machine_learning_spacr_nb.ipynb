# %%
# Description: Train a ML model to classigy cells based on measurement data
import spacr
from spacr.ml import generate_ml_scores
# %matplotlib inline

srcs = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3',
       '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4']

settings = {'src':srcs,
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':2,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':False,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)

# %%
# Description: Train a ML model to classigy cells based on measurement data
import spacr
from spacr.ml import generate_ml_scores
# %matplotlib inline

settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
            'model_type_ml':'xgboost',
            'heatmap_feature':'predictions',
            'grouping':'mean',
            'min_max':'allq',
            'cmap':'viridis',
            'n_estimators':1000,
            'test_size':0.1,
            'location_column':'column_name',
            'positive_control':'c2',
            'negative_control':'c1',
            'exclude':None,
            'pathogen_limit':3,
            'nuclei_limit':1,
            'n_repeats':10,
            'reg_alpha':0.1,
            'reg_lambda':1.0,
            'learning_rate':0.001,
            'top_features':30,
            'channel_of_interest':1,
            'minimum_cell_count':0,
            'remove_low_variance_features':True,
            'remove_highly_correlated_features':True,
            'prune_features':False,
            'cross_validation':True,
            'verbose':True,
            'n_jobs':28}

results = spacr.ml.generate_ml_scores(settings)
# Out:
# Models already downloaded to: /home/carruthers/anaconda3/envs/spacr/lib/python3.9/site-packages/spacr/resources/models
#                                   Key  \
# 0                                 src
# 1                       model_type_ml
# 2                     heatmap_feature
# 3                            grouping
# 4                             min_max
# 5                                cmap
# 6                        n_estimators
# 7                           test_size
# 8                     location_column
# 9                    positive_control
# 10                   negative_control
# 11                            exclude
# 12                     pathogen_limit
# 13                       nuclei_limit
# 14                          n_repeats
# 15                          reg_alpha
# 16                         reg_lambda
# 17                      learning_rate
# 18                       top_features
# 19                channel_of_interest
# 20                 minimum_cell_count
# 21       remove_low_variance_features
# 22  remove_highly_correlated_features
# 23                     prune_features
# 24                   cross_validation
# 25                            verbose
# 26                             n_jobs
# 27                  annotation_column
# 28                         save_to_db
#
#                                                 Value
# 0   /nas_mnt/carruthers/Einar/tsg101_screen/TSG101...
# 1                                             xgboost
# 2                                         predictions
# 3                                                mean
# 4                                                allq
# 5                                             viridis
# 6                                                1000
# 7                                                 0.1
# 8                                         column_name
# 9                                                  c2
# 10                                                 c1
# 11                                               None
# 12                                                  3
# 13                                                  1
# 14                                                 10
# 15                                                0.1
# 16                                                1.0
# 17                                              0.001
# 18                                                 30
# 19                                                  1
# 20                                                  0
# 21                                               True
# 22                                               True
# 23                                              False
# 24                                               True
# 25                                               True
# 26                                                 28
# 27                                               None
# 28                                              False
# cell: 60816
# nucleus: 80889
# pathogen: 111317
# cytoplasm: 60816
# cells: 60816, cells grouped: 60816
# cytoplasms: 60816, cytoplasms grouped: 60816
# nucleus: 80889, nucleus grouped: 60816
# pathogens: 76887, pathogens grouped: 54617
# Generated dataframe with: 791 columns and 54617 rows
# Columns to remove: ['nucleus_cell_id', 'nucleus_prcfo_count', 'pathogen_cell_id', 'pathogen_prcfo_count', 'pathogen_pathogen', 'nucleus_nucleus']
# Removed columns: ['object_label', 'plate', 'row_name', 'column_name', 'field', 'prcf', 'file_name', 'path_name', 'prc', 'cell_area', 'cell_area_filled', 'cell_area_bbox', 'cell_convex_area', 'cell_major_axis_length', 'cell_minor_axis_length', 'cell_eccentricity', 'cell_solidity', 'cell_extent', 'cell_perimeter', 'cell_euler_number', 'cell_equivalent_diameter_area', 'cell_feret_diameter_max', 'cell_zernike_0', 'cell_zernike_1', 'cell_zernike_2', 'cell_zernike_3', 'cell_zernike_4', 'cell_zernike_5', 'cell_zernike_6', 'cell_zernike_7', 'cell_zernike_8', 'cell_zernike_9', 'cell_zernike_10', 'cell_zernike_11', 'cell_zernike_12', 'cell_zernike_13', 'cell_zernike_14', 'cell_zernike_15', 'cell_zernike_16', 'cell_zernike_17', 'cell_zernike_18', 'cell_zernike_19', 'cell_zernike_20', 'cell_zernike_21', 'cell_zernike_22', 'cell_zernike_23', 'cell_zernike_24', 'cell_channel_0_centroid_weighted-0', 'cell_channel_0_centroid_weighted-1', 'cell_channel_0_centroid_weighted_local-0', 'cell_channel_0_centroid_weighted_local-1', 'cell_channel_0_max_intensity', 'cell_channel_0_mean_intensity', 'cell_channel_0_min_intensity', 'cell_channel_0_percentile_5', 'cell_channel_0_percentile_10', 'cell_channel_0_percentile_25', 'cell_channel_0_percentile_50', 'cell_channel_0_percentile_75', 'cell_channel_0_percentile_85', 'cell_channel_0_percentile_95', 'cell_channel_0_shannon_entropy', 'cell_channel_0_homogeneity_distance_8', 'cell_channel_0_homogeneity_distance_16', 'cell_channel_0_homogeneity_distance_32', 'cell_channel_0_cell_channel_0_blur', 'cell_channel_2_centroid_weighted-0', 'cell_channel_2_centroid_weighted-1', 'cell_channel_2_centroid_weighted_local-0', 'cell_channel_2_centroid_weighted_local-1', 'cell_channel_2_max_intensity', 'cell_channel_2_mean_intensity', 'cell_channel_2_min_intensity', 'cell_channel_2_percentile_5', 'cell_channel_2_percentile_10', 'cell_channel_2_percentile_25', 'cell_channel_2_percentile_50', 'cell_channel_2_percentile_75', 'cell_channel_2_percentile_85', 'cell_channel_2_percentile_95', 'cell_channel_2_shannon_entropy', 'cell_channel_2_homogeneity_distance_8', 'cell_channel_2_homogeneity_distance_16', 'cell_channel_2_homogeneity_distance_32', 'cell_channel_2_cell_channel_2_blur', 'cell_channel_3_centroid_weighted-0', 'cell_channel_3_centroid_weighted-1', 'cell_channel_3_centroid_weighted_local-0', 'cell_channel_3_centroid_weighted_local-1', 'cell_channel_3_max_intensity', 'cell_channel_3_mean_intensity', 'cell_channel_3_min_intensity', 'cell_channel_3_percentile_5', 'cell_channel_3_percentile_10', 'cell_channel_3_percentile_25', 'cell_channel_3_percentile_50', 'cell_channel_3_percentile_75', 'cell_channel_3_percentile_85', 'cell_channel_3_percentile_95', 'cell_channel_3_shannon_entropy', 'cell_channel_3_homogeneity_distance_8', 'cell_channel_3_homogeneity_distance_16', 'cell_channel_3_homogeneity_distance_32', 'cell_channel_3_cell_channel_3_blur', 'cell_channel_0_channel_2_Pearson_correlation', 'cell_channel_0_channel_2_M1_correlation_15', 'cell_channel_0_channel_2_M2_correlation_15', 'cell_channel_0_channel_2_M1_correlation_85', 'cell_channel_0_channel_2_M2_correlation_85', 'cell_channel_0_channel_2_M1_correlation_95', 'cell_channel_0_channel_2_M2_correlation_95', 'cell_channel_0_channel_3_Pearson_correlation', 'cell_channel_0_channel_3_M1_correlation_15', 'cell_channel_0_channel_3_M2_correlation_15', 'cell_channel_0_channel_3_M1_correlation_85', 'cell_channel_0_channel_3_M2_correlation_85', 'cell_channel_0_channel_3_M1_correlation_95', 'cell_channel_0_channel_3_M2_correlation_95', 'cell_channel_1_channel_2_Pearson_correlation', 'cell_channel_1_channel_2_M1_correlation_15', 'cell_channel_1_channel_2_M2_correlation_15', 'cell_channel_1_channel_2_M1_correlation_85', 'cell_channel_1_channel_2_M2_correlation_85', 'cell_channel_1_channel_2_M1_correlation_95', 'cell_channel_1_channel_2_M2_correlation_95', 'cell_channel_1_channel_3_Pearson_correlation', 'cell_channel_1_channel_3_M1_correlation_15', 'cell_channel_1_channel_3_M2_co ...
# Removed columns due to low variance: ['cell_channel_1_percentile_5', 'cell_channel_1_homogeneity_distance_8', 'cell_channel_0_channel_1_M1_correlation_15', 'cell_channel_0_channel_1_M2_correlation_15', 'cell_channel_0_channel_1_M1_correlation_85', 'cell_channel_0_channel_1_M2_correlation_85', 'cell_channel_0_channel_1_M1_correlation_95', 'cell_channel_0_channel_1_M2_correlation_95', 'cytoplasm_channel_1_percentile_5', 'cytoplasm_channel_1_percentile_10', 'cytoplasm_channel_1_percentile_25', 'cytoplasm_channel_1_homogeneity_distance_8', 'cytoplasm_channel_1_homogeneity_distance_16', 'cytoplasm_channel_1_homogeneity_distance_32', 'cytoplasm_channel_0_channel_1_M1_correlation_15', 'cytoplasm_channel_0_channel_1_M2_correlation_15', 'cytoplasm_channel_0_channel_1_M1_correlation_85', 'cytoplasm_channel_0_channel_1_M2_correlation_85', 'cytoplasm_channel_0_channel_1_M1_correlation_95', 'cytoplasm_channel_0_channel_1_M2_correlation_95', 'nucleus_channel_1_homogeneity_distance_8', 'nucleus_channel_1_homogeneity_distance_16', 'nucleus_channel_1_homogeneity_distance_32', 'nucleus_channel_0_channel_1_M1_correlation_15', 'nucleus_channel_0_channel_1_M2_correlation_15', 'nucleus_channel_0_channel_1_M1_correlation_85', 'nucleus_channel_0_channel_1_M2_correlation_85', 'nucleus_channel_0_channel_1_M1_correlation_95', 'nucleus_channel_0_channel_1_M2_correlation_95', 'pathogen_channel_1_homogeneity_distance_8', 'pathogen_channel_1_homogeneity_distance_16', 'pathogen_channel_0_channel_1_M1_correlation_15', 'pathogen_channel_0_channel_1_M2_correlation_15', 'pathogen_channel_0_channel_1_M1_correlation_85', 'pathogen_channel_0_channel_1_M2_correlation_85', 'pathogen_channel_0_channel_1_M1_correlation_95', 'pathogen_channel_0_channel_1_M2_correlation_95']
# Removed columns due to high correlation: ['cell_channel_1_percentile_85', 'cell_channel_1_homogeneity_distance_32', 'cytoplasm_channel_1_centroid_weighted-0', 'cytoplasm_channel_1_centroid_weighted-1', 'cytoplasm_channel_1_centroid_weighted_local-0', 'cytoplasm_channel_1_centroid_weighted_local-1', 'cytoplasm_channel_1_min_intensity', 'cytoplasm_channel_1_shannon_entropy', 'nucleus_channel_1_centroid_weighted-0', 'nucleus_channel_1_percentile_75', 'nucleus_channel_1_percentile_85', 'nucleus_channel_1_shannon_entropy', 'nucleus_channel_1_periphery_10_percentile', 'nucleus_channel_1_periphery_25_percentile', 'nucleus_channel_1_periphery_50_percentile', 'nucleus_channel_1_periphery_75_percentile', 'nucleus_channel_1_periphery_85_percentile', 'nucleus_channel_1_outside_mean', 'nucleus_channel_1_outside_10_percentile', 'nucleus_channel_1_outside_25_percentile', 'nucleus_channel_1_outside_50_percentile', 'nucleus_channel_1_outside_75_percentile', 'nucleus_channel_1_outside_85_percentile', 'pathogen_channel_1_centroid_weighted-0', 'pathogen_channel_1_percentile_75', 'pathogen_channel_1_percentile_85', 'pathogen_channel_1_shannon_entropy', 'pathogen_channel_1_periphery_10_percentile', 'pathogen_channel_1_periphery_25_percentile', 'pathogen_channel_1_periphery_50_percentile', 'pathogen_channel_1_periphery_75_percentile', 'pathogen_channel_1_periphery_85_percentile', 'pathogen_channel_1_outside_10_percentile', 'pathogen_channel_1_outside_25_percentile', 'pathogen_channel_1_outside_50_percentile', 'pathogen_channel_1_outside_75_percentile', 'pathogen_channel_1_outside_85_percentile', 'pathogen_rad_dist_channel_1_bin_0']
# Dropped 2 columns with NaN values
# After filtration: 54617
# Found 71 numerical features in the dataframe
# Features used in training: ['cell_channel_1_centroid_weighted-0', 'cell_channel_1_centroid_weighted-1', 'cell_channel_1_centroid_weighted_local-0', 'cell_channel_1_centroid_weighted_local-1', 'cell_channel_1_max_intensity', 'cell_channel_1_mean_intensity', 'cell_channel_1_min_intensity', 'cell_channel_1_percentile_10', 'cell_channel_1_percentile_25', 'cell_channel_1_percentile_50', 'cell_channel_1_percentile_75', 'cell_channel_1_percentile_95', 'cell_channel_1_shannon_entropy', 'cell_channel_1_homogeneity_distance_16', 'cell_channel_1_cell_channel_1_blur', 'cell_channel_0_channel_1_Pearson_correlation', 'cytoplasm_channel_1_max_intensity', 'cytoplasm_channel_1_mean_intensity', 'cytoplasm_channel_1_percentile_50', 'cytoplasm_channel_1_percentile_75', 'cytoplasm_channel_1_percentile_85', 'cytoplasm_channel_1_percentile_95', 'cytoplasm_channel_1_cytoplasm_channel_1_blur', 'cytoplasm_channel_0_channel_1_Pearson_correlation', 'nucleus_channel_1_centroid_weighted-1', 'nucleus_channel_1_centroid_weighted_local-0', 'nucleus_channel_1_centroid_weighted_local-1', 'nucleus_channel_1_max_intensity', 'nucleus_channel_1_mean_intensity', 'nucleus_channel_1_min_intensity', 'nucleus_channel_1_percentile_5', 'nucleus_channel_1_percentile_10', 'nucleus_channel_1_percentile_25', 'nucleus_channel_1_percentile_50', 'nucleus_channel_1_percentile_95', 'nucleus_channel_1_periphery_mean', 'nucleus_channel_1_periphery_5_percentile', 'nucleus_channel_1_periphery_95_percentile', 'nucleus_channel_1_outside_5_percentile', 'nucleus_channel_1_outside_95_percentile', 'nucleus_channel_1_nucleus_channel_1_blur', 'nucleus_rad_dist_channel_1_bin_0', 'nucleus_rad_dist_channel_1_bin_1', 'nucleus_rad_dist_channel_1_bin_2', 'nucleus_rad_dist_channel_1_bin_3', 'nucleus_rad_dist_channel_1_bin_4', 'nucleus_rad_dist_channel_1_bin_5', 'pathogen_channel_1_centroid_weighted-1', 'pathogen_channel_1_centroid_weighted_local-0', 'pathogen_channel_1_centroid_weighted_local-1', 'pathogen_channel_1_max_intensity', 'pathogen_channel_1_mean_intensity', 'pathogen_channel_1_min_intensity', 'pathogen_channel_1_percentile_5', 'pathogen_channel_1_percentile_10', 'pathogen_channel_1_percentile_25', 'pathogen_channel_1_percentile_50', 'pathogen_channel_1_percentile_95', 'pathogen_channel_1_homogeneity_distance_32', 'pathogen_channel_1_periphery_mean', 'pathogen_channel_1_periphery_5_percentile', 'pathogen_channel_1_periphery_95_percentile', 'pathogen_channel_1_outside_mean', 'pathogen_channel_1_outside_5_percentile', 'pathogen_channel_1_outside_95_percentile', 'pathogen_channel_1_pathogen_channel_1_blur', 'pathogen_rad_dist_channel_1_bin_1', 'pathogen_rad_dist_channel_1_bin_2', 'pathogen_rad_dist_channel_1_bin_3', 'pathogen_rad_dist_channel_1_bin_4', 'pathogen_rad_dist_channel_1_bin_5']
# Features: ['cell_channel_1_centroid_weighted-0', 'cell_channel_1_centroid_weighted-1', 'cell_channel_1_centroid_weighted_local-0', 'cell_channel_1_centroid_weighted_local-1', 'cell_channel_1_max_intensity', 'cell_channel_1_mean_intensity', 'cell_channel_1_min_intensity', 'cell_channel_1_percentile_10', 'cell_channel_1_percentile_25', 'cell_channel_1_percentile_50', 'cell_channel_1_percentile_75', 'cell_channel_1_percentile_95', 'cell_channel_1_shannon_entropy', 'cell_channel_1_homogeneity_distance_16', 'cell_channel_1_cell_channel_1_blur', 'cell_channel_0_channel_1_Pearson_correlation', 'cytoplasm_channel_1_max_intensity', 'cytoplasm_channel_1_mean_intensity', 'cytoplasm_channel_1_percentile_50', 'cytoplasm_channel_1_percentile_75', 'cytoplasm_channel_1_percentile_85', 'cytoplasm_channel_1_percentile_95', 'cytoplasm_channel_1_cytoplasm_channel_1_blur', 'cytoplasm_channel_0_channel_1_Pearson_correlation', 'nucleus_channel_1_centroid_weighted-1', 'nucleus_channel_1_centroid_weighted_local-0', 'nucleus_channel_1_centroid_weighted_local-1', 'nucleus_channel_1_max_intensity', 'nucleus_channel_1_mean_intensity', 'nucleus_channel_1_min_intensity', 'nucleus_channel_1_percentile_5', 'nucleus_channel_1_percentile_10', 'nucleus_channel_1_percentile_25', 'nucleus_channel_1_percentile_50', 'nucleus_channel_1_percentile_95', 'nucleus_channel_1_periphery_mean', 'nucleus_channel_1_periphery_5_percentile', 'nucleus_channel_1_periphery_95_percentile', 'nucleus_channel_1_outside_5_percentile', 'nucleus_channel_1_outside_95_percentile', 'nucleus_channel_1_nucleus_channel_1_blur', 'nucleus_rad_dist_channel_1_bin_0', 'nucleus_rad_dist_channel_1_bin_1', 'nucleus_rad_dist_channel_1_bin_2', 'nucleus_rad_dist_channel_1_bin_3', 'nucleus_rad_dist_channel_1_bin_4', 'nucleus_rad_dist_channel_1_bin_5', 'pathogen_channel_1_centroid_weighted-1', 'pathogen_channel_1_centroid_weighted_local-0', 'pathogen_channel_1_centroid_weighted_local-1', 'pathogen_channel_1_max_intensity', 'pathogen_channel_1_mean_intensity', 'pathogen_channel_1_min_intensity', 'pathogen_channel_1_percentile_5', 'pathogen_channel_1_percentile_10', 'pathogen_channel_1_percentile_25', 'pathogen_channel_1_percentile_50', 'pathogen_channel_1_percentile_95', 'pathogen_channel_1_homogeneity_distance_32', 'pathogen_channel_1_periphery_mean', 'pathogen_channel_1_periphery_5_percentile', 'pathogen_channel_1_periphery_95_percentile', 'pathogen_channel_1_outside_mean', 'pathogen_channel_1_outside_5_percentile', 'pathogen_channel_1_outside_95_percentile', 'pathogen_channel_1_pathogen_channel_1_blur', 'pathogen_rad_dist_channel_1_bin_1', 'pathogen_rad_dist_channel_1_bin_2', 'pathogen_rad_dist_channel_1_bin_3', 'pathogen_rad_dist_channel_1_bin_4', 'pathogen_rad_dist_channel_1_bin_5']
# Found 5836 samples for c1 and 7804 samples for c2. Total: 13640
# Fold 1 - Optimal threshold: 0.5148403644561768
# Fold 1 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1168
#            1       0.89      0.91      0.90      1560
#
#     accuracy                           0.89      2728
#    macro avg       0.89      0.88      0.88      2728
# weighted avg       0.89      0.89      0.89      2728
#
# Fold 2 - Optimal threshold: 0.5556339025497437
# Fold 2 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      1167
#            1       0.89      0.92      0.90      1561
#
#     accuracy                           0.89      2728
#    macro avg       0.89      0.88      0.88      2728
# weighted avg       0.89      0.89      0.89      2728
#
# Fold 3 - Optimal threshold: 0.529425323009491
# Fold 3 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86      1167
#            1       0.88      0.92      0.90      1561
#
#     accuracy                           0.88      2728
#    macro avg       0.88      0.87      0.88      2728
# weighted avg       0.88      0.88      0.88      2728
# Fold 4 - Optimal threshold: 0.4846925139427185
# Fold 4 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87      1167
#            1       0.89      0.91      0.90      1561
#
#     accuracy                           0.89      2728
#    macro avg       0.89      0.88      0.88      2728
# weighted avg       0.89      0.89      0.89      2728
#
# Fold 5 - Optimal threshold: 0.4998561441898346
# Fold 5 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1167
#            1       0.87      0.91      0.89      1561
#
#     accuracy                           0.87      2728
#    macro avg       0.87      0.87      0.87      2728
# weighted avg       0.87      0.87      0.87      2728
#
#
# Final Classification Report on Full Dataset:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 34
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       6 settings = {'src':'/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
#       7             'model_type_ml':'xgboost',
#       8             'heatmap_feature':'predictions',
#    (...)
#      31             'verbose':True,
#      32             'n_jobs':28}
# ---> 34 results = spacr.ml.generate_ml_scores(settings)
#
# File ~/anaconda3/envs/spacr/lib/python3.9/site-packages/spacr/ml.py:1231, in generate_ml_scores(settings)
#    1228     if f"pathogen_channel_{settings['channel_of_interest']}_mean_intensity" and f"cytoplasm_channel_{settings['channel_of_interest']}_mean_intensity" in df.columns:
#    1229         df['recruitment'] = df[f"pathogen_channel_{settings['channel_of_interest']}_mean_intensity"]/df[f"cytoplasm_channel_{settings['channel_of_interest']}_mean_intensity"]
# -> 1231 output, figs = ml_analysis(df,
#    1232                            settings['channel_of_interest'],
#    1233                            settings['location_column'],
#    1234                            settings['positive_control'],
#    1235                            settings['negative_control'],
#    1236                            settings['exclude'],
#    1237                            settings['n_repeats'],
#    1238                            settings['top_features'],
#    1239                            settings['reg_alpha'],
#    1240                            settings['reg_lambda'],
#    1241                            settings['learning_rate'],
#    1242                            settings['n_estimators'],
#    1243                            settings['test_size'],
#    1244                            settings['model_type_ml'],
#    1245                            settings['n_jobs'],
#    1246                            settings['remove_low_variance_features'],
#    1247                            settings['remove_highly_correlated_features'],
#    1248                            settings['prune_features'],
#    1249                            settings['cross_validation'],
#    1250                            settings['verbose'])
#    1252 shap_fig = shap_analysis(output[3], output[4], output[5])
#    1254 features = output[0].select_dtypes(include=[np.number]).columns.tolist()
#
# File ~/anaconda3/envs/spacr/lib/python3.9/site-packages/spacr/ml.py:1447, in ml_analysis(df, channel_of_interest, location_column, positive_control, negative_control, exclude, n_repeats, top_features, reg_alpha, reg_lambda, learning_rate, n_estimators, test_size, model_type, n_jobs, remove_low_variance_features, remove_highly_correlated_features, prune_features, cross_validation, verbose)
#    1445 if verbose:
#    1446     print("\nFinal Classification Report on Full Dataset:")
# -> 1447     print(classification_report(y, all_predictions))
#    1449 # Generate metrics DataFrame
#    1450 final_report_dict = classification_report(y, all_predictions, output_dict=True)
#
# File ~/anaconda3/envs/spacr/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/anaconda3/envs/spacr/lib/python3.9/site-packages/sklearn/metrics/_classification.py:2626, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2491 @validate_params(
#    2492     {
#    2493         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    2517     zero_division="warn",
#    2518 ):
#    2519     """Build a text report showing the main classification metrics.
#    2520
#    2521     Read more in the :ref:`User Guide <classification_report>`.
#    (...)
#    2623     <BLANKLINE>
#    2624     """
# -> 2626     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2628     if labels is None:
#    2629         labels = unique_labels(y_true, y_pred)
#
# File ~/anaconda3/envs/spacr/lib/python3.9/site-packages/sklearn/metrics/_classification.py:103, in _check_targets(y_true, y_pred)
#      76 """Check that y_true and y_pred belong to the same classification task.
#      77
#      78 This converts multiclass or binary types to a common shape, and raises a
#    (...)
#     100 y_pred : array or indicator matrix
#     101 """
#     102 xp, _ = get_namespace(y_true, y_pred)
# --> 103 check_consistent_length(y_true, y_pred)
#     104 type_true = type_of_target(y_true, input_name="y_true")
#     105 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~/anaconda3/envs/spacr/lib/python3.9/site-packages/sklearn/utils/validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [13640, 54617]

# %%
srcs  = ['/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240810_132824/plate1',
        '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240824_072829/plate2',
        '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240825_094106/plate3',
        '/nas_mnt/carruthers/Einar/tsg101_screen/TSG101SCREEN_20240826_140251/plate4']

for src in srcs:
    settings['src'] = src
    for channel_of_interest in [None, 0,1,2,3, [0,1], [0,2],[0,3],[1,2],[1,3],[2,3],[0,1,2],[1,2,3], 'morphology']:
        settings['channel_of_interest'] = channel_of_interest
        results = spacr.ml.generate_ml_scores(settings)

# %%
# Description: Fix a regression model to estimate the effect size of gRNAs on cell scores.

from spacr.ml import perform_regression
import pandas as pd
# %matplotlib inline

settings = {'count_data':'path',
            'score_data':'path',
            'highlight':'string',
            'fraction_threshold':0.1,
            'dependent_variable': 'prediction_probability_class_1',
            'transform':'log',
            'agg_type':'median',
            'min_cell_count':25,
            'regression_type':'ols',
            'random_row_column_effects':False,
            'plate':None,
            'cov_type':None,
            'alpha':0.8,
            'nc':'c1',
            'pc':'c2',
            'other':'c3'}

coef_df = perform_regression(settings)
