# %%
# Description: use this cell to generate train and test folders: datasets/train/nc and pc and datasets/test/nc and pc
from spacr.io import generate_training_dataset

settings = {'src':'/nas_mnt/carruthers/yifan/Yifan_Einar screen/yifanUbtrial11h_20240705_184432/plate1', # (path) path to source folder (where origional images were stored)
            'dataset_mode':'metadata_annotation', # (string) annotation, measurement, metadata, annotation_metadata
            'tables':['cell'],# (list of strings) The tabels present in the database, excluding png_list
            'test_split':0.1, # (float) Fraction of images used for the test set
            'annotation_column':'test', # (Optional, string) If using mode annotation, The annotation column in the database
            'annotated_classes':[1], # (Optional, list of integers) If using mode annotation, The interger in annotation_column, if len(annotated_classes) is 1, class 2 will be generated from a random selection of images.
            'metadata_type_by':'column_name', # (Optional, strin) If using mode medatada, If using mode medatada,the column class_metadata elements are in
            'class_metadata':['c10','c11','c12','c22','c23','c24'], # (Optional, list of lists of strings) If using mode medatada, the elements that deffine each class 
            'png_type':'cell_png', # (Optional, string) string in the path of each image (used to filter images)
            'nuclei_limit':False, # (Optional, bool) if cell and nucleus in tables, filter for number of nuclei per cell
            'pathogen_limit':0, # (Optional, integer) if cell and pathogen in tables, filter for number of pathogen per cell
            'uninfected':True, # (Optional, bool) if cell and pathogen in tables, bool for uninfected cells (cells)
            'size':None # (Optional, integer or NoneType) limit for number of images to include in total (test + train) per class
           }

generate_training_dataset(settings)

# %%
# Description: train a torch model
from spacr.deep_spacr import train_test_model

settings = {'src':'/nas_mnt/carruthers/yifan/Yifan_Einar screen/yifanUbtrial11h_20240705_184432/plate1/datasets/training', # (path) path to source folder (ends with datasets/training)
            'train':True, # (bool) - Train
            'test': False, # (bool) - Test
            'custom_model':False, # (path) - path to a custom model
            'classes':['nc','pc'], # (list) - list of classes (folder names in dataset/training/train or test)
            'model_type':'maxvit_t', # (string) - Name of torch model architecture
            'optimizer_type':'adamw', # (string) - type of optimizer
            'schedule':'reduce_lr_on_plateau', # (string) - type of scheduler (reduce_lr_on_plateau or step_lr)
            'loss_type':'focal_loss', # (string) - Loss function (binary_cross_entropy_with_logits or focal_loss)
            'normalize':True, # (bool) - Apply ImageNet normalization to images before training.
            'image_size':224, # (int) - Size of images, height and width.
            'batch_size':64, # (int) - Nr. of images per batch
            'epochs':100, # (int) - Nr. of epochs for training
            'val_split':0.1, # (float) - Fraction of images in validation dataset
            'learning_rate':0.0001, # (float) - Learning rate per epoch
            'weight_decay':0.00001, # (float) - Fraction of random weights decay (regularization)
            'dropout_rate':0.1, # (float) - Fraction of weights to omit per epoch (regularization)
            'init_weights':True, # (bool) - Initiate model with ImageNet weights
            'amsgrad':True, # (bool) - guard against exploding gradients
            'use_checkpoint':True, # (bool) - checkpoint gradient calculations to save VRAM at the expence of computation
            'gradient_accumulation':True, # (bool) - Accumulate gradients to mimic larger batches
            'gradient_accumulation_steps':4, # (int) - Epochs to accumulate gradients
            'intermedeate_save':True, # Save intermediate states of the model
            'pin_memory':True, # (bool) - Whether to pin memory for the data loader
            'n_jobs':30, # (int) - Number of threads to use
            'train_channels':['r','g','b'], # (list of 'r', 'g', and/or 'b') - PNG channels to use for training
            'augment':False, # (bool) - Augment the dataset, vertical, horizontal flip and rotate each image to artificially expand the dataset 8 fold.
            'verbose':True}

train_test_model(settings)
# Out:
# Models already downloaded to: /home/carruthers/anaconda3/envs/spacr/lib/python3.9/site-packages/spacr/resources/models
#                             Key  \
# 0                           src
# 1                         train
# 2                          test
# 3                  custom_model
# 4                       classes
# 5                    model_type
# 6                optimizer_type
# 7                      schedule
# 8                     loss_type
# 9                     normalize
# 10                   image_size
# 11                   batch_size
# 12                       epochs
# 13                    val_split
# 14                learning_rate
# 15                 weight_decay
# 16                 dropout_rate
# 17                 init_weights
# 18                      amsgrad
# 19               use_checkpoint
# 20        gradient_accumulation
# 21  gradient_accumulation_steps
# 22            intermedeate_save
# 23                   pin_memory
# 24                       n_jobs
# 25               train_channels
# 26                      augment
# 27                      verbose
# 28                          dst
#
#                                                 Value
# 0   /nas_mnt/carruthers/yifan/Yifan_Einar screen/y...
# 1                                                True
# 2                                               False
# 3                                               False
# 4                                            [nc, pc]
# 5                                            maxvit_t
# 6                                               adamw
# 7                                reduce_lr_on_plateau
# 8                                          focal_loss
# 9                                                True
# 10                                                224
# 11                                                 64
# 12                                                100
# 13                                                0.1
# 14                                             0.0001
# 15                                            0.00001
# 16                                                0.1
# 17                                               True
# 18                                               True
# 19                                               True
# 20                                               True
# 21                                                  4
# 22                                               True
# 23                                               True
# 24                                                 30
# 25                                          [r, g, b]
# 26                                              False
# 27                                               True
# 28  /nas_mnt/carruthers/yifan/Yifan_Einar screen/y...
# Training a network on channels: [1, 2, 3]
# Channel 1: Red, Channel 2: Green, Channel 3: Blue
# Loading Train and validation datasets
# Train data:4863, Validation data:541
# Generating Dataloader with 30 workers
# Train batches:76, Validation batches:9
# Using cuda for Torch
# Loading Model to cuda...ecture: maxvit_t init_weights: True dropout_rate: 0.1 use_checkpoint: True
# Training ...
# Progress: 1/100, operation_type: Training, Train Loss: 0.005, Val Loss: 0.048, Train acc.: 0.525, Val acc.: 0.530, Train NC acc.: 0.052, Val NC acc.: 0.067, Train PC acc.: 0.999, Val PC acc.: 0.993, Train PRAUC: 0.802, Val PRAUC: 0.794
# Progress: 2/100, operation_type: Training, Train Loss: 0.003, Val Loss: 0.021, Train acc.: 0.800, Val acc.: 0.791, Train NC acc.: 0.609, Val NC acc.: 0.611, Train PC acc.: 0.991, Val PC acc.: 0.970, Train PRAUC: 0.949, Val PRAUC: 0.930
# Progress: 3/100, operation_type: Training, Train Loss: 0.002, Val Loss: 0.039, Train acc.: 0.895, Val acc.: 0.876, Train NC acc.: 0.806, Val NC acc.: 0.793, Train PC acc.: 0.984, Val PC acc.: 0.959, Train PRAUC: 0.982, Val PRAUC: 0.965
# Progress: 4/100, operation_type: Training, Train Loss: 0.001, Val Loss: 0.006, Train acc.: 0.950, Val acc.: 0.906, Train NC acc.: 0.948, Val NC acc.: 0.904, Train PC acc.: 0.951, Val PC acc.: 0.908, Train PRAUC: 0.991, Val PRAUC: 0.974
# Nc class accuracy: 0.9481907894736842 Pc class Accuracy: 0.951048951048951
# Found: 94.0% accurate model
# Progress: 5/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.037, Train acc.: 0.945, Val acc.: 0.908, Train NC acc.: 0.904, Val NC acc.: 0.867, Train PC acc.: 0.986, Val PC acc.: 0.948, Train PRAUC: 0.993, Val PRAUC: 0.973
# Progress: 6/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.009, Train acc.: 0.977, Val acc.: 0.921, Train NC acc.: 0.979, Val NC acc.: 0.941, Train PC acc.: 0.974, Val PC acc.: 0.900, Train PRAUC: 0.997, Val PRAUC: 0.975
# Nc class accuracy: 0.9786184210526315 Pc class Accuracy: 0.9744960921431509
# Found: 95.0% accurate model
# Progress: 7/100, operation_type: Training, Train Loss: 0.001, Val Loss: 0.035, Train acc.: 0.963, Val acc.: 0.900, Train NC acc.: 0.997, Val NC acc.: 0.974, Train PC acc.: 0.929, Val PC acc.: 0.827, Train PRAUC: 0.998, Val PRAUC: 0.976
# Progress: 8/100, operation_type: Training, Train Loss: 0.001, Val Loss: 0.018, Train acc.: 0.986, Val acc.: 0.922, Train NC acc.: 0.980, Val NC acc.: 0.922, Train PC acc.: 0.992, Val PC acc.: 0.923, Train PRAUC: 0.999, Val PRAUC: 0.978
# Nc class accuracy: 0.9798519736842105 Pc class Accuracy: 0.9921842863019333
# Found: 95.0% accurate model
# Progress: 9/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.014, Train acc.: 0.990, Val acc.: 0.924, Train NC acc.: 0.987, Val NC acc.: 0.922, Train PC acc.: 0.992, Val PC acc.: 0.926, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 0.9872532894736842 Pc class Accuracy: 0.9921842863019333
# Found: 98.0% accurate model
# Progress: 10/100, operation_type: Training, Train Loss: 0.001, Val Loss: 0.014, Train acc.: 0.991, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.963, Train PC acc.: 0.982, Val PC acc.: 0.889, Train PRAUC: 1.000, Val PRAUC: 0.973
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9823118058412176
# Found: 98.0% accurate model
# Progress: 11/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.019, Train acc.: 0.989, Val acc.: 0.921, Train NC acc.: 1.000, Val NC acc.: 0.978, Train PC acc.: 0.978, Val PC acc.: 0.863, Train PRAUC: 1.000, Val PRAUC: 0.976
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9777869189633895
# Found: 95.0% accurate model
# Progress: 12/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.025, Train acc.: 0.998, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.967, Train PC acc.: 0.997, Val PC acc.: 0.886, Train PRAUC: 1.000, Val PRAUC: 0.976
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9967091731797614
# Found: 99.0% accurate model
# Progress: 13/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.054, Train acc.: 0.997, Val acc.: 0.922, Train NC acc.: 1.000, Val NC acc.: 0.963, Train PC acc.: 0.995, Val PC acc.: 0.882, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 0.9995888157894737 Pc class Accuracy: 0.9950637597696421
# Found: 99.0% accurate model
# Progress: 14/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.044, Train acc.: 0.998, Val acc.: 0.937, Train NC acc.: 1.000, Val NC acc.: 0.974, Train PC acc.: 0.996, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.976
# Nc class accuracy: 0.9995888157894737 Pc class Accuracy: 0.9958864664747018
# Found: 99.0% accurate model
# Progress: 15/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.047, Train acc.: 0.999, Val acc.: 0.932, Train NC acc.: 1.000, Val NC acc.: 0.959, Train PC acc.: 0.998, Val PC acc.: 0.904, Train PRAUC: 1.000, Val PRAUC: 0.978
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9979432332373509
# Found: 99.0% accurate model
# Progress: 16/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.025, Train acc.: 0.998, Val acc.: 0.933, Train NC acc.: 1.000, Val NC acc.: 0.985, Train PC acc.: 0.995, Val PC acc.: 0.882, Train PRAUC: 1.000, Val PRAUC: 0.977
# Nc class accuracy: 1.0 Pc class Accuracy: 0.995475113122172
# Found: 99.0% accurate model
# Progress: 17/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.006, Train acc.: 1.000, Val acc.: 0.930, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.904, Train PRAUC: 1.000, Val PRAUC: 0.976
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 18/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.047, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 19/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.022, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 20/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.048, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.897, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 21/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.028, Train acc.: 1.000, Val acc.: 0.930, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.904, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 22/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.022, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 23/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.018, Train acc.: 1.000, Val acc.: 0.933, Train NC acc.: 1.000, Val NC acc.: 0.974, Train PC acc.: 1.000, Val PC acc.: 0.893, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 24/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.000, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 25/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.034, Train acc.: 1.000, Val acc.: 0.930, Train NC acc.: 1.000, Val NC acc.: 0.948, Train PC acc.: 1.000, Val PC acc.: 0.911, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 26/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.062, Train acc.: 1.000, Val acc.: 0.930, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.904, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 27/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.035, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 28/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.000, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.944, Train PC acc.: 1.000, Val PC acc.: 0.908, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 29/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.004, Train acc.: 1.000, Val acc.: 0.933, Train NC acc.: 1.000, Val NC acc.: 0.970, Train PC acc.: 1.000, Val PC acc.: 0.897, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 30/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.028, Train acc.: 1.000, Val acc.: 0.924, Train NC acc.: 1.000, Val NC acc.: 0.948, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 31/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.046, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.948, Train PC acc.: 1.000, Val PC acc.: 0.908, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 32/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.051, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 33/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.033, Train acc.: 1.000, Val acc.: 0.932, Train NC acc.: 1.000, Val NC acc.: 0.963, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 34/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.000, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 35/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.071, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.904, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 36/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.011, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.904, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 37/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.007, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.975
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 38/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.006, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 39/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.012, Train acc.: 1.000, Val acc.: 0.928, Train NC acc.: 1.000, Val NC acc.: 0.956, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 40/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.030, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 41/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.062, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 42/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.003, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 43/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.018, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 44/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.002, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 45/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.049, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 46/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.018, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 47/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.011, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 48/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.038, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 49/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.071, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 50/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.006, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 51/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.009, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 52/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.000, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 53/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.005, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 54/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.021, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 55/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.002, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 56/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.003, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 57/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.000, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 58/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.015, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 59/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.040, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 60/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.008, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 61/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.008, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 62/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.000, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 63/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.094, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 64/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.042, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 65/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.024, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 66/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.099, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 67/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.021, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 68/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.019, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 69/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.027, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 70/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.051, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 71/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.065, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 72/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.028, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 73/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.019, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 74/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.020, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 75/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.004, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 76/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.025, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 77/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.059, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 78/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.012, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 79/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.001, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 80/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.028, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 81/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.041, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 82/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.074, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 83/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.000, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 84/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.039, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 85/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.004, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 86/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.011, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 87/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.048, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 88/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.019, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 89/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.036, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 90/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.070, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 91/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.042, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 92/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.029, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 93/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.038, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 94/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.003, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 95/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.009, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 96/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.065, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 97/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.006, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 98/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.081, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 99/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.048, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# Nc class accuracy: 1.0 Pc class Accuracy: 0.9995886466474702
# Found: 99.0% accurate model
# Progress: 100/100, operation_type: Training, Train Loss: 0.000, Val Loss: 0.057, Train acc.: 1.000, Val acc.: 0.926, Train NC acc.: 1.000, Val NC acc.: 0.952, Train PC acc.: 1.000, Val PC acc.: 0.900, Train PRAUC: 1.000, Val PRAUC: 0.974
# '/nas_mnt/carruthers/yifan/Yifan_Einar screen/yifanUbtrial11h_20240705_184432/plate1/datasets/training/model/maxvit_t/rgb/epochs_100/maxvit_t_epoch_100_channels_rgb.pth'

# %%
# Description: generate a tar dataset

from spacr.io import generate_dataset

settings = {'src':'path', # (path) path to source folder (where origional images were stored)
           'file_metadata':'cell_png', # (Optional, string) string in the path of each image (used to filter images)
           'experiment':'test', # (string) - Name of dataset
           'sample':10000} # (Optional, integer or NoneType) limit for number of images to include in the dataset

generate_dataset(settings)

# %%
# Description: apply a model to a tar dataset

from spacr.deep_spacr import apply_model_to_tar

settings = {'dataset':'path.tar', # (path) - path to tar dataset (ends with .tar) 
            'model_path':'path.pth', # (path) - path to model (ends with .pth) 
            'file_type':'cell_png', # (Optional, string) string in the path of each image (used to filter images)
            'image_size':224, # (int) - Size of images, height and width
            'batch_size':64, # (int) - Nr. of images per batch
            'normalize':True, # (bool) - Apply ImageNet normalization to images before training.
            'score_threshold':0.5, # (float) - Score to byass the classes
            'n_jobs':30, # (int) - Number of threads to use
            'verbose':True}

result_df = apply_model_to_tar(settings)

# %%
# Description: Fit a regression model to estimate the effect size of gRNAs on cell scores.
from spacr.ml import perform_regression
import pandas as pd
# %matplotlib inline

settings = {'count_data':'path', # (path) path or list of paths to sequencing count data
            'score_data':'path', # (path) path or list of paths to score data
            'score_column':'column', # () - column with cell scores
            'metadata_files':['path.csv','path.csv'], # (list) pahts to gene metadata 
            'positive_control':'gene', # (string) - gene to highlight in volcano plot
            'negative_control':'gene', # (string) - gene to highlight in volcano plot
            'min_n':3, # () - 
            'fraction_threshold':None, # (Optional, float or NoneType) - Minimum threshold for gene fraction, if None automatically calculated
            'target_unique_count':5, # () - Number of expected unique gRNAs per well
            'tolerance':0.02, # (float) - Tollerance for cells per well limit
            'log_x':False, # () - gRNA Fraction plot X axis log
            'log_y':False, # () - gRNA Fraction plot Y axis log
            'x_lim':None, # () - Volcano X axis limit
            'control_wells':['c1','c2','c3'], # (list) - Metadata to exclude from regression model
            'filter_column':'column', # (str) - Column containing control metadata to remove
            'dependent_variable': 'column', # (string) - Dependent variable for regression
            'threshold_method':'var', # (string) - effect size thresold type (std or var)
            'threshold_multiplier':4, # (integer) - effect size threshold multiplyer 
            'transform':'log', # (string) - Transform dependent variable
            'agg_type':'mean', # (string) - aggregation for dependent variable
            'min_cell_count':None, # (integer) - Minimum number of cells per well
            'regression_type':'ols', # (string) - Type of regression (ols, glm, mixed, ridge, lasso).
            'random_row_column_effects':False, # (bool) - Remove plate , row and column random effects.
            'y_lims':[[0,9], [12, 16]], # (list of lists) limits for broken y axis
            'plate':None, # (string or NoneType) - strinf to replace plate column values with
            'cov_type':None, # (string) - covariance type for ols regression
            'volcano':'gene', # (string) - mode for significant resuls (gene, grna, all)
            'alpha':0.8} # (float) - alpha for hinge and lasso regression

coef_df = perform_regression(settings)
