# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from environmental_risk_metrics import EsaLandCover, EsriLandCover, OpenLandMapLandCover
from IPython.display import Image

# Configure logging to display in Jupyter
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    force=True,  # This ensures the configuration is applied even if logging was previously configured
)
logger = logging.getLogger(__name__)


esa_land_cover = EsaLandCover(use_esri_classes=True)

polygon = {
    "type": "Feature",
    "properties": {},
    "geometry": {
        "coordinates": [
            [
                [10.235198982658801, 51.42076009745068],
                [10.236477278753114, 51.41697045550828],
                [10.244461712820623, 51.41823370440062],
                [10.242888425319222, 51.4220355049745],
                [10.235198982658801, 51.42076009745068],
            ]
        ],
        "type": "Polygon",
    },
}

start_date = "2000-01-01"
end_date = "2024-12-31"

# %%
luc = esa_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    resolution=0.00009
)

class_percentages = esa_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=0.00009
)

class_percentages
# Out:
# 2024-12-19 17:54:27,831 - environmental_risk_metrics.metrics.land_use_change - INFO - Loading ['esa-cci-lc'] data at 9e-05m resolution
# 2024-12-19 17:54:27,978 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 17:54:28,397 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 21 items
# 100%|██████████| 21/21 [00:00<00:00, 597.11it/s]
# 2024-12-19 17:54:28,512 - environmental_risk_metrics.metrics.land_use_change - INFO - Loading ['esa-cci-lc'] data at 9e-05m resolution
# 2024-12-19 17:54:28,646 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 17:54:28,971 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 21 items
# 100%|██████████| 21/21 [00:00<00:00, 515.07it/s]
# lccs_class  Crops
# time
# 2000-01-01  100.0
# 2001-01-01  100.0
# 2002-01-01  100.0
# 2003-01-01  100.0
# 2004-01-01  100.0
# 2005-01-01  100.0
# 2006-01-01  100.0
# 2007-01-01  100.0
# 2008-01-01  100.0
# 2009-01-01  100.0
# 2010-01-01  100.0
# 2011-01-01  100.0
# 2012-01-01  100.0
# 2013-01-01  100.0
# 2014-01-01  100.0
# 2015-01-01  100.0
# 2016-01-01  100.0
# 2017-01-01  100.0
# 2018-01-01  100.0
# 2019-01-01  100.0
# 2020-01-01  100.0

# %%
esri_land_cover = EsriLandCover()

esri = esri_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    resolution=10
)

esri_percentages = esri_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=10
)

esri_percentages
# Out:
# 2024-12-19 17:54:31,115 - environmental_risk_metrics.metrics.land_use_change - INFO - Loading ['io-lulc-annual-v02'] data at 10m resolution
# 2024-12-19 17:54:31,247 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 17:54:31,675 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 7 items
# 100%|██████████| 7/7 [00:00<00:00, 17.67it/s]
# 2024-12-19 17:54:32,085 - environmental_risk_metrics.metrics.land_use_change - INFO - Loading ['io-lulc-annual-v02'] data at 10m resolution
# 2024-12-19 17:54:32,208 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 17:54:32,548 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 7 items
# 100%|██████████| 7/7 [00:00<00:00, 131.65it/s]
# data        Crops
# time
# 2017-01-01  100.0
# 2018-01-01  100.0
# 2019-01-01  100.0
# 2020-01-01  100.0
# 2021-01-01  100.0
# 2022-01-01  100.0
# 2023-01-01  100.0

# %%
from environmental_risk_metrics import EsaLandCover, EsriLandCover, OpenLandMapLandCover

olanm_land_cover = OpenLandMapLandCover()

olanm = olanm_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    resolution=10
)
olanm
# Out:
# 2024-12-19 17:54:49,991 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 17:54:50,029 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20050101_20051231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 17:54:50,133 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20100101_20101231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 17:54:50,173 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20150101_20151231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 17:54:50,214 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20200101_20201231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# <xarray.DataArray (time: 5, y: 19, x: 34)> Size: 3kB
# array([[[250, 250, 250, ..., 250,  43,  45],
#         [250, 250, 244, ..., 250,  43,  43],
#         [250, 250, 244, ...,  40,  41,  42],
#         ...,
#         [244,  24,  24, ..., 244, 244, 244],
#         [ 24,  24,  24, ..., 244, 244, 244],
#         [ 24,  24,  24, ..., 244, 244, 244]],
#
#        [[250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ...,  40,  44,  43],
#         ...,
#         [244,  24,  24, ..., 244, 244, 244],
#         [ 24,  24,  24, ..., 244, 244, 244],
#         [ 24,  24,  24, ..., 244, 244, 244]],
#
#        [[250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ...,  29,  32,  36],
#         ...,
#         [244,  24,  24, ..., 244, 244, 244],
#         [ 24,  24,  24, ..., 244, 244, 244],
#         [ 24,  24,  24, ..., 244, 244, 244]],
#
#        [[250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ...,  24,  28,  27],
#         ...,
#         [244, 244,  24, ..., 244, 244, 244],
#         [244, 244, 244, ..., 244, 244, 244],
#         [244, 244, 244, ..., 244, 244, 244]],
#
#        [[250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ...,  34,  40,  29],
#         ...,
#         [244, 244,  24, ..., 244, 244, 244],
#         [244, 244, 244, ..., 244, 244, 244],
#         [244, 244, 244, ..., 244, 244, 244]]],
#       shape=(5, 19, 34), dtype=uint8)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 272B 10.24 10.24 10.24 10.24 ... 10.24 10.24 10.24
#   * y            (y) float64 152B 51.42 51.42 51.42 51.42 ... 51.42 51.42 51.42
#   * time         (time) datetime64[ns] 40B 2000-01-01 2005-01-01 ... 2020-01-01
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Area
#     scale_factor:   1.0
#     add_offset:     0.0

# %%
olanm_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=10
)
# Out:
# 2024-12-19 17:54:36,933 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 17:54:36,948 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20050101_20051231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 17:54:36,963 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20100101_20101231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 17:54:36,976 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20150101_20151231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 17:54:36,994 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20200101_20201231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# ---------------------------------------------------------------------------
# NoDataInBounds                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 olanm_land_cover.get_land_use_class_percentages(
#       2     start_date=start_date,
#       3     end_date=end_date,
#       4     polygon=polygon,
#       5     polygon_crs="EPSG:4326",
#       6     resolution=10
#       7 )
#
# File ~/risk-reports/src/environmental_risk_metrics/metrics/land_use_change.py:653, in OpenLandMapLandCover.get_land_use_class_percentages(self, start_date, end_date, polygon, polygon_crs, resolution, all_touched)
#     643 def get_land_use_class_percentages(
#     644     self,
#     645     start_date: str,
#    (...)
#     650     all_touched: bool = True,
#     651 ) -> pd.DataFrame:
#     652     ds = self.load_xarray(start_date, end_date, polygon, polygon_crs, resolution)
# --> 653     clipped_data = ds.rio.write_crs(polygon_crs).rio.clip(
#     654         [polygon], polygon_crs, all_touched=all_touched
#     655     )
#     656     clipped_data_df = clipped_data.to_dataframe("class").reset_index()
#     657     clipped_data_df = clipped_data_df[clipped_data_df["class"] != 0]
#
# File ~/risk-reports/.venv/lib/python3.12/site-packages/rioxarray/raster_array.py:974, in RasterArray.clip(self, geometries, crs, all_touched, drop, invert, from_disk)
#     962     cropped_ds = _clip_xarray(
#     963         self._obj,
#     964         geometries=geometries,
#    (...)
#     967         invert=invert,
#     968     )
#     970 if (
#     971     cropped_ds.coords[self.x_dim].size < 1
#     972     or cropped_ds.coords[self.y_dim].size < 1
#     973 ):
# --> 974     raise NoDataInBounds(
#     975         f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     976     )
#     978 # make sure correct attributes preserved & projection added
#     979 _add_attrs_proj(new_data_array=cropped_ds, src_data_array=self._obj)
#
# NoDataInBounds: No data found in bounds.

# %%
luc = esa_land_cover.load_xarray(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    resolution=0.00009
)

class_percentages = esa_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=0.00009
)

class_percentages
# Out:
# 2024-12-19 17:54:59,655 - environmental_risk_metrics.metrics.land_use_change - INFO - Loading ['esa-cci-lc'] data at 9e-05m resolution
# 2024-12-19 17:54:59,783 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 17:55:00,138 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 21 items
# 100%|██████████| 21/21 [00:00<00:00, 490.77it/s]
# 2024-12-19 17:55:00,199 - environmental_risk_metrics.metrics.land_use_change - INFO - Loading ['esa-cci-lc'] data at 9e-05m resolution
# 2024-12-19 17:55:00,322 - environmental_risk_metrics.utils.planetary_computer - INFO - Searching for Sentinel-2 items between 2000-01-01 and 2024-12-31
# 2024-12-19 17:55:00,714 - environmental_risk_metrics.utils.planetary_computer - INFO - Found 21 items
# 100%|██████████| 21/21 [00:00<00:00, 402.89it/s]
# lccs_class  Crops
# time
# 2000-01-01  100.0
# 2001-01-01  100.0
# 2002-01-01  100.0
# 2003-01-01  100.0
# 2004-01-01  100.0
# 2005-01-01  100.0
# 2006-01-01  100.0
# 2007-01-01  100.0
# 2008-01-01  100.0
# 2009-01-01  100.0
# 2010-01-01  100.0
# 2011-01-01  100.0
# 2012-01-01  100.0
# 2013-01-01  100.0
# 2014-01-01  100.0
# 2015-01-01  100.0
# 2016-01-01  100.0
# 2017-01-01  100.0
# 2018-01-01  100.0
# 2019-01-01  100.0
# 2020-01-01  100.0

# %%
import geopandas as gpd
polygon_df = gpd.GeoDataFrame.from_features([polygon])
minx, miny, maxx, maxy = polygon_df.bounds.iloc[
            0
        ]
minx, miny, maxx, maxy
# Out:
# (10.235198982658801, 51.41697045550828, 10.244461712820623, 51.4220355049745)

# %%
olanm_land_cover = OpenLandMapLandCover(use_esri_classes=True)

olanm_percentages = olanm_land_cover.get_land_use_class_percentages(
    start_date=start_date,
    end_date=end_date,
    polygon=polygon,
    polygon_crs="EPSG:4326",
    resolution=10
)
olanm_percentages
# Out:
# 2024-12-19 15:10:49,283 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20000101_20001231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 15:10:49,299 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20050101_20051231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 15:10:49,314 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20100101_20101231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 15:10:49,326 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20150101_20151231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# 2024-12-19 15:10:49,340 - rasterio._env - WARNING - CPLE_AppDefined in lc_glad.glcluc_c_30m_s_20200101_20201231_go_epsg.4326_v20230901.tif: This file used to have optimizations in its layout, but those have been, at least partly, invalidated by later changes
# /Users/thimmzwiener/risk-reports/.venv/lib/python3.12/site-packages/xarray/core/duck_array_ops.py:226: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)
# class       Built area  Crops  Rangeland  Trees
# time
# 2000-01-01        3.70  94.34       1.74   0.22
# 2005-01-01       17.21  82.14       0.65   0.00
# 2010-01-01       17.21  82.14       0.65   0.00
# 2015-01-01       17.21  82.14       0.65   0.00
# 2020-01-01       18.08  81.26       0.65   0.00
