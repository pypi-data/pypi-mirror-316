# %% [markdown]
# # XProj demo

# %%
import numpy as np
import shapely
import xarray as xr
import xvec

import xproj

xr.set_options(display_expand_indexes=True);

# %% [markdown]
# ## Example datasets

# %% [markdown]
# - Vector data cube (https://xvec.readthedocs.io) with no CRS attached

# %%
rng = np.random.default_rng(1234)
random_points = shapely.points(rng.uniform(-180, 180, 10), rng.uniform(-90, 90, 10))

ds_vec = xr.Dataset(coords={"points": ("space", random_points)}).set_xindex(
    "points", xvec.GeometryIndex
)

ds_vec
# Out:
# <xarray.Dataset> Size: 80B
# Dimensions:  (space: 10)
# Coordinates:
#   * points   (space) object 80B POINT (171.61191601133118 -10.618898030367944...
# Dimensions without coordinates: space
# Data variables:
#     *empty*
# Indexes:
#     points   GeometryIndex (crs=None)

# %% [markdown]
# ## Set the CRS
#
# `.proj.assign_crs()` can be used to set the CRS: it creates a new scalar coordinate (if it doesn't exist yet) with a `xproj.CRSIndex`.
#
# Note: the name of the spatial reference coordinate is abritrary ("spatial_ref" is a common name).

# %%
ds_wgs84 = ds_vec.proj.assign_crs(spatial_ref="epsg:4326")

ds_wgs84
# Out:
# <xarray.Dataset> Size: 88B
# Dimensions:      (space: 10)
# Coordinates:
#   * points       (space) object 80B POINT (171.61191601133118 -10.61889803036...
#   * spatial_ref  int64 8B 0
# Dimensions without coordinates: space
# Data variables:
#     *empty*
# Indexes:
#     points       GeometryIndex (crs=None)
#     spatial_ref  CRSIndex (crs=EPSG:4326)

# %% [markdown]
# ## Get the CRS

# %% [markdown]
# Via the `.proj.crs` property, which returns a [pyproj.CRS](https://pyproj4.github.io/pyproj/stable/api/crs/crs.html) object.

# %%
ds_wgs84.proj.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# Alternatively, it is possible to explicitly pass the CRS coordinate name to the `.proj` accessor:

# %%
ds_wgs84.proj("spatial_ref").crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## CRS-aware alignment
#
# The index of the CRS coordinate is used to compare or align xarray objects based on their CRS.

# %%
ds_pseudo_mercator = ds_wgs84.proj.assign_crs(spatial_ref="epsg:3857", allow_override=True)

# %% [markdown]
# Note the nice error message when trying to combine two datasets with different CRS (only works if the CRS coordinates have the same name), raised by Xarray and leveraging `pyproj.CRS`'s repr to output detailled information.

# %%
ds_wgs84 + ds_pseudo_mercator
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ds_wgs84 + ds_pseudo_mercator
#
# File ~/miniconda3/envs/xproj_dev/lib/python3.12/site-packages/xarray/core/_typed_ops.py:204, in DatasetOpsMixin.__add__(self, other)
#     203 def __add__(self, other: DsCompatible) -> Self | DataTree:
# --> 204     return self._binary_op(other, operator.add)
#
# File ~/miniconda3/envs/xproj_dev/lib/python3.12/site-packages/xarray/core/dataset.py:7900, in Dataset._binary_op(self, other, f, reflexive, join)
#    7898     self, other = align(self, other, join=align_type, copy=False)
#    7899 g = f if not reflexive else lambda x, y: f(y, x)
# -> 7900 ds = self._calculate_binary_op(g, other, join=align_type)
#    7901 keep_attrs = _get_keep_attrs(default=False)
#    7902 if keep_attrs:
#
# File ~/miniconda3/envs/xproj_dev/lib/python3.12/site-packages/xarray/core/dataset.py:7961, in Dataset._calculate_binary_op(self, f, other, join, inplace)
#    7958     return type(self)(new_data_vars)
#    7960 other_coords: Coordinates | None = getattr(other, "coords", None)
# -> 7961 ds = self.coords.merge(other_coords)
#    7963 if isinstance(other, Dataset):
#    7964     new_vars = apply_over_both(
#    7965         self.data_vars, other.data_vars, self.variables, other.variables
#    7966     )
#
# File ~/miniconda3/envs/xproj_dev/lib/python3.12/site-packages/xarray/core/coordinates.py:522, in Coordinates.merge(self, other)
#     519 if not isinstance(other, Coordinates):
#     520     other = Dataset(coords=other).coords
# --> 522 coords, indexes = merge_coordinates_without_align([self, other])
#     523 coord_names = set(coords)
#     524 return Dataset._construct_direct(
#     525     variables=coords, coord_names=coord_names, indexes=indexes
#     526 )
#
# File ~/miniconda3/envs/xproj_dev/lib/python3.12/site-packages/xarray/core/merge.py:413, in merge_coordinates_without_align(objects, prioritized, exclude_dims, combine_attrs)
#     409     filtered = collected
#     411 # TODO: indexes should probably be filtered in collected elements
#     412 # before merging them
# --> 413 merged_coords, merged_indexes = merge_collected(
#     414     filtered, prioritized, combine_attrs=combine_attrs
#     415 )
#     416 merged_indexes = filter_indexes_from_coords(merged_indexes, set(merged_coords))
#     418 return merged_coords, merged_indexes
#
# File ~/miniconda3/envs/xproj_dev/lib/python3.12/site-packages/xarray/core/merge.py:269, in merge_collected(grouped, prioritized, compat, combine_attrs, equals)
#     265 for other_var, other_index in indexed_elements[1:]:
#     266     if not indexes_equal(
#     267         index, other_index, variable, other_var, index_cmp_cache
#     268     ):
# --> 269         raise MergeError(
#     270             f"conflicting values/indexes on objects to be combined for coordinate {name!r}\n"
#     271             f"first index: {index!r}\nsecond index: {other_index!r}\n"
#     272             f"first variable: {variable!r}\nsecond variable: {other_var!r}\n"
#     273         )
#     274 if compat == "identical":
#     275     for other_variable, _ in indexed_elements[1:]:
#
# MergeError: conflicting values/indexes on objects to be combined for coordinate 'spatial_ref'
# first index: CRSIndex
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
#
# second index: CRSIndex
# <Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich
#
# first variable: <xarray.Variable ()> Size: 8B
# array(0)
# second variable: <xarray.Variable ()> Size: 8B
# array(0)

# %% [markdown]
# This also works seamlessly with `xarray.concat()`:

# %%
xr.concat([ds_wgs84.isel(space=[0, 1]), ds_wgs84.isel(space=[-1])], "space")
# Out:
# <xarray.Dataset> Size: 32B
# Dimensions:      (space: 3)
# Coordinates:
#   * points       (space) object 24B POINT (171.61191601133118 -10.61889803036...
#   * spatial_ref  int64 8B 0
# Dimensions without coordinates: space
# Data variables:
#     *empty*
# Indexes:
#     points       GeometryIndex (crs=None)
#     spatial_ref  CRSIndex (crs=EPSG:4326)

# %% [markdown]
# It is possible to combine heterogeneous geospatial Datasets (e.g., raster, vector, grid, mesh) as long as they all have a spatial reference coordinate with the same name and with a `CRSIndex`.

# %%
# lat-lon rectilinear grid

ds_grid = xr.Dataset(coords={"lat": np.linspace(-90, 90, 10), "lon": np.linspace(-180, 180, 20)})
ds_grid_wgs84 = ds_grid.proj.assign_crs(spatial_ref="epsg:4326")

# merge the lat-lon grid with the vector data cube
xr.merge([ds_wgs84, ds_grid_wgs84])
# Out:
# <xarray.Dataset> Size: 328B
# Dimensions:      (space: 10, lat: 10, lon: 20)
# Coordinates:
#   * points       (space) object 80B POINT (171.61191601133118 -10.61889803036...
#   * spatial_ref  int64 8B 0
#   * lat          (lat) float64 80B -90.0 -70.0 -50.0 -30.0 ... 50.0 70.0 90.0
#   * lon          (lon) float64 160B -180.0 -161.1 -142.1 ... 142.1 161.1 180.0
# Dimensions without coordinates: space
# Data variables:
#     *empty*
# Indexes:
#     points       GeometryIndex (crs=None)
#     spatial_ref  CRSIndex (crs=EPSG:4326)

# %% [markdown]
# ## Unset the CRS
#
# Just drop the CRS index and/or coordinate

# %%
ds_no_crs = ds_wgs84.drop_vars("spatial_ref")

ds_no_crs
# Out:
# <xarray.Dataset> Size: 80B
# Dimensions:  (space: 10)
# Coordinates:
#   * points   (space) object 80B POINT (171.61191601133118 -10.618898030367944...
# Dimensions without coordinates: space
# Data variables:
#     *empty*
# Indexes:
#     points   GeometryIndex (crs=None)

# %% [markdown]
# It is possible to combine datasets with and without a defined CRS. The resulting dataset will have the common CRS found among all datasets.

# %%
ds_wgs84 + ds_no_crs
# Out:
# <xarray.Dataset> Size: 88B
# Dimensions:      (space: 10)
# Coordinates:
#   * points       (space) object 80B POINT (171.61191601133118 -10.61889803036...
#   * spatial_ref  int64 8B 0
# Dimensions without coordinates: space
# Data variables:
#     *empty*
# Indexes:
#     points       GeometryIndex (crs=None)
#     spatial_ref  CRSIndex (crs=EPSG:4326)
