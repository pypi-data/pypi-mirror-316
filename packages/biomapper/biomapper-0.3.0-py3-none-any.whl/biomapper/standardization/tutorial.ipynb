# %%
# RaMP-DB API Client Tutorial

"""
This tutorial demonstrates how to use the RaMP-DB API client module
for metabolic pathway and biochemical data analysis.
"""

from typing import List, Dict
from ramp_client import RaMPClient, RaMPConfig, RaMPAPIError
import time

def main():
    # 1. Initialize the client
    # You can use default settings
    client = RaMPClient()
    
    # Or customize the configuration
    custom_config = RaMPConfig(
        base_url="https://rampdb.nih.gov/api",
        timeout=60  # Extended timeout for larger queries
    )
    client_custom = RaMPClient(config=custom_config)

    # 2. Basic Database Information
    try:
        # Get source database versions
        versions = client.get_source_versions()
        print("Database versions:", versions)

        # Get valid ID types
        id_types = client.get_id_types()
        print("Valid ID types:", id_types)
    except RaMPAPIError as e:
        print(f"Error getting database info: {e}")

    # 3. Metabolite Analysis Example
    def analyze_metabolites(metabolite_ids: List[str]):
        try:
            # Add 'hmdb:' prefix if not present
            formatted_ids = [
                f"hmdb:{mid}" if not mid.startswith("hmdb:") else mid 
                for mid in metabolite_ids
            ]
            
            # Get chemical properties
            properties = client.get_chemical_properties(formatted_ids)
            print("\nChemical properties:")
            print(properties)

            # Get chemical classes
            classes = client.get_chemical_classes(formatted_ids)
            print("\nChemical classes:")
            print(classes)

            # Get pathways
            pathways = client.get_pathways_from_analytes(formatted_ids)
            
            # Analyze pathway statistics
            if "result" in pathways and pathways["result"]:
                stats = client.analyze_pathway_stats(pathways)
                for metabolite_id, pathway_stats in stats.items():
                    print(f"\nPathway stats for {metabolite_id}:")
                    print(f"Total pathways: {pathway_stats.total_pathways}")
                    print(f"Pathways by source: {pathway_stats.pathways_by_source}")
                    print(f"Unique pathway names: {len(pathway_stats.unique_pathway_names)}")
                    print(f"Pathway sources: {pathway_stats.pathway_sources}")

                # Find pathway overlaps
                overlaps = client.find_pathway_overlaps(pathways)
                print("\nPathway overlaps:")
                for pathway, count in overlaps.items():
                    if count > 1:  # Show only pathways shared by multiple metabolites
                        print(f"{pathway}: shared by {count} metabolites")
            else:
                print("No pathway data found")

        except RaMPAPIError as e:
            print(f"Error in metabolite analysis: {e}")

    # 4. Protein Pathway Analysis Example
    def analyze_protein_pathways(protein_ids: List[str]):
        try:
            # Format protein IDs with uniprot prefix for pathway analysis
            formatted_protein_ids = [
                f"uniprot:{pid}" if not pid.startswith("uniprot:") else pid 
                for pid in protein_ids
            ]
            
            # Get pathways associated with proteins
            protein_pathways = client.get_pathways_from_analytes(formatted_protein_ids)
            print("\nProtein pathways:")
            print(protein_pathways)

            # Analyze pathway statistics
            if "result" in protein_pathways and protein_pathways["result"]:
                stats = client.analyze_pathway_stats(protein_pathways)
                for protein_id, pathway_stats in stats.items():
                    print(f"\nPathway stats for {protein_id}:")
                    print(f"Total pathways: {pathway_stats.total_pathways}")
                    print(f"Pathways by source: {pathway_stats.pathways_by_source}")
                    print(f"Unique pathway names: {len(pathway_stats.unique_pathway_names)}")
                    print(f"Pathway sources: {pathway_stats.pathway_sources}")
            else:
                print("No pathway data found")

        except RaMPAPIError as e:
            print(f"Error in protein pathway analysis: {e}")

    # 5. Combined Analysis Example
    def analyze_metabolites_and_proteins(
        metabolite_ids: List[str], protein_ids: List[str]
    ):
        try:
            # Combine IDs with appropriate prefixes
            combined_analytes = (
                [f"hmdb:{mid}" if not mid.startswith("hmdb:") else mid 
                 for mid in metabolite_ids] +
                [f"uniprot:{pid}" if not pid.startswith("uniprot:") else pid 
                 for pid in protein_ids]
            )

            # Get common reaction analytes
            common_reactions = client.get_common_reaction_analytes(combined_analytes)
            print("\nCommon reaction analytes:")
            print(common_reactions)

            # Attempt to get reactions with retry
            max_retries = 3
            for attempt in range(max_retries):
                try:
                    reactions = client.get_reactions_from_analytes(combined_analytes)
                    print("\nReactions:")
                    print(reactions)
                    break
                except RaMPAPIError as e:
                    if attempt == max_retries - 1:
                        print(f"Failed to get reactions after {max_retries} attempts: {e}")
                    else:
                        time.sleep(2)  # Wait before retry

            # Attempt to get reaction classes with retry
            for attempt in range(max_retries):
                try:
                    reaction_classes = client.get_reaction_classes(combined_analytes)
                    print("\nReaction classes:")
                    print(reaction_classes)
                    break
                except RaMPAPIError as e:
                    if attempt == max_retries - 1:
                        print(f"Failed to get reaction classes after {max_retries} attempts: {e}")
                    else:
                        time.sleep(2)  # Wait before retry

        except RaMPAPIError as e:
            print(f"Error in combined analysis: {e}")

    # 6. Ontology Analysis Example
    def analyze_ontologies(metabolite_ids: List[str], ontology_terms: List[str]):
        try:
            # Format metabolite IDs
            formatted_ids = [
                f"hmdb:{mid}" if not mid.startswith("hmdb:") else mid 
                for mid in metabolite_ids
            ]
            
            # Get ontologies from metabolites
            ontologies = client.get_ontologies_from_metabolites(
                formatted_ids, names_or_ids="ids"
            )
            print("\nOntologies for metabolites:")
            print(ontologies)

            # Attempt to get metabolites from ontologies with retry
            max_retries = 3
            for attempt in range(max_retries):
                try:
                    metabolites = client.get_metabolites_from_ontologies(
                        ontology_terms, output_format="json"
                    )
                    print("\nMetabolites for ontologies:")
                    print(metabolites)
                    break
                except RaMPAPIError as e:
                    if attempt == max_retries - 1:
                        print(f"Failed to get metabolites from ontologies after {max_retries} attempts: {e}")
                    else:
                        time.sleep(2)  # Wait before retry

        except RaMPAPIError as e:
            print(f"Error in ontology analysis: {e}")

    # 7. Chemical Enrichment Analysis Example
    def perform_enrichment_analysis(metabolite_ids: List[str]):
        try:
            # Format metabolite IDs
            formatted_ids = [
                f"hmdb:{mid}" if not mid.startswith("hmdb:") else mid 
                for mid in metabolite_ids
            ]
            
            # Attempt enrichment analysis with retry
            max_retries = 3
            for attempt in range(max_retries):
                try:
                    enrichment_results = client.perform_chemical_enrichment(formatted_ids)
                    print("\nChemical enrichment results:")
                    print(enrichment_results)
                    break
                except RaMPAPIError as e:
                    if attempt == max_retries - 1:
                        print(f"Failed to perform enrichment analysis after {max_retries} attempts: {e}")
                    else:
                        time.sleep(2)  # Wait before retry

        except RaMPAPIError as e:
            print(f"Error in enrichment analysis: {e}")

    # Example usage with real metabolite and protein IDs
    metabolite_ids = ["HMDB0000001", "HMDB0000002"]  # Example metabolite IDs
    protein_ids = ["P31323", "P04637"]  # Example protein IDs
    ontology_terms = ["CHEBI:15903"]  # Example ontology terms

    print("\n=== Metabolite Analysis ===")
    analyze_metabolites(metabolite_ids)

    print("\n=== Protein Pathway Analysis ===")
    analyze_protein_pathways(protein_ids)

    print("\n=== Combined Analysis ===")
    analyze_metabolites_and_proteins(metabolite_ids, protein_ids)

    print("\n=== Ontology Analysis ===")
    analyze_ontologies(metabolite_ids, ontology_terms)

    print("\n=== Enrichment Analysis ===")
    perform_enrichment_analysis(metabolite_ids)

if __name__ == "__main__":
    main()
# Out:
# Database versions: {'data': [{'ramp_db_version': '2.5.2', 'db_mod_date': '2024-03-27 08:19:31.246126', 'status': 'current', 'data_source_id': 'hmdb', 'data_source_name': 'HMDB', 'data_source_url': 'https://hmdb.ca/', 'data_source_version': 'v5.0 (2021-11-17)'}, {'ramp_db_version': '2.5.2', 'db_mod_date': '2024-03-27 08:19:31.246126', 'status': 'current', 'data_source_id': 'reactome', 'data_source_name': 'Reactome', 'data_source_url': 'https://reactome.org/', 'data_source_version': 'v87 (Dec 2023)'}, {'ramp_db_version': '2.5.2', 'db_mod_date': '2024-03-27 08:19:31.246126', 'status': 'current', 'data_source_id': 'wiki', 'data_source_name': 'WikiPathways', 'data_source_url': 'https://www.wikipathways.org/index.php/WikiPathways', 'data_source_version': 'v20240210 (2024-02-10)'}, {'ramp_db_version': '2.5.2', 'db_mod_date': '2024-03-27 08:19:31.246126', 'status': 'current', 'data_source_id': 'kegg', 'data_source_name': 'KEGG', 'data_source_url': 'https://www.genome.jp/kegg/', 'data_source_version': 'from HMDB (v5.0) (2021-11-17) '}, {'ramp_db_version': '2.5.2', 'db_mod_date': '2024-03-27 08:19:31.246126', 'status': 'current', 'data_source_id': 'chebi', 'data_source_name': 'ChEBI', 'data_source_url': 'https://www.ebi.ac.uk/chebi/', 'data_source_version': 'Release 231 (2024-03-01)'}, {'ramp_db_version': '2.5.2', 'db_mod_date': '2024-03-27 08:19:31.246126', 'status': 'current', 'data_source_id': 'lipidmaps', 'data_source_name': 'Lipid Maps', 'data_source_url': 'https://www.lipidmaps.org/', 'data_source_version': 'Release 2024-03-06'}, {'ramp_db_version': '2.5.2', 'db_mod_date': '2024-03-27 08:19:31.246126', 'status': 'current', 'data_source_id': 'rhea', 'data_source_name': 'Rhea', 'data_source_url': 'https://www.rhea-db.org/', 'data_source_version': 'Release 131 (2024-01-)'}], 'function_call': 'RaMP::getCurrentRaMPSourceDBVersions()'}
# Valid ID types: {'data': [{'analyteType': 'Metabolites', 'idTypes': 'hmdb, chebi, chemspider, kegg, pubchem, CAS, wikidata, LIPIDMAPS, lipidbank, swisslipids, plantfa, kegg_glycan, rhea-comp, polymer'}, {'analyteType': 'Genes/Proteins', 'idTypes': 'ensembl, gene_symbol, uniprot, entrez, hmdb, wikidata, EN, ncbiprotein, brenda, chebi'}], 'function_call': 'RaMP::getPrefixesFromAnalytes("metabolite"); RaMP::getPrefixesFromAnalytes("gene")'}
#
# === Metabolite Analysis ===
#
# Chemical properties:
# {'data': [{'chem_data_source': 'hmdb', 'chem_source_id': 'hmdb:HMDB0000001', 'iso_smiles': '[H]OC(=O)[C@@]([H])(N([H])[H])C([H])([H])C1=C([H])N(C([H])=N1)C([H])([H])[H]', 'inchi_key_prefix': 'BRMWTNUJHUMWMS', 'inchi_key': 'BRMWTNUJHUMWMS-LURJTMIESA-N', 'inchi': 'InChI=1S/C7H11N3O2/c1-10-3-5(9-4-10)2-6(8)7(11)12/h3-4,6H,2,8H2,1H3,(H,11,12)/t6-/m0/s1', 'mw': 169.1811, 'monoisotop_mass': 169.0851, 'common_name': '1-Methylhistidine', 'mol_formula': 'C7H11N3O2'}, {'chem_data_source': 'hmdb', 'chem_source_id': 'hmdb:HMDB0000002', 'iso_smiles': 'NCCCN', 'inchi_key_prefix': 'XFNJVJPLKCPIBV', 'inchi_key': 'XFNJVJPLKCPIBV-UHFFFAOYSA-N', 'inchi': 'InChI=1S/C3H10N2/c4-2-1-3-5/h1-5H2', 'mw': 74.1249, 'monoisotop_mass': 74.0844, 'common_name': '1,3-Diaminopropane', 'mol_formula': 'C3H10N2'}], 'function_call': ['RaMP::getChemicalProperties(c("hmdb:HMDB0000001", "hmdb:HMDB0000002"))\n'], 'numFoundIds': [2]}
#
# Chemical classes:
# {'data': [{'sourceId': 'hmdb:HMDB0000001', 'common_names': '1-Methylhistidine', 'class_level_name': 'ClassyFire_class', 'class_name': 'Carboxylic acids and derivatives', 'source': 'hmdb', 'directIdClassHits': 2}, {'sourceId': 'hmdb:HMDB0000001', 'common_names': '1-Methylhistidine', 'class_level_name': 'ClassyFire_sub_class', 'class_name': 'Amino acids, peptides, and analogues', 'source': 'hmdb', 'directIdClassHits': 2}, {'sourceId': 'hmdb:HMDB0000001', 'common_names': '1-Methylhistidine', 'class_level_name': 'ClassyFire_super_class', 'class_name': 'Organic acids and derivatives', 'source': 'hmdb', 'directIdClassHits': 2}, {'sourceId': 'hmdb:HMDB0000002', 'common_names': '1,3-Diaminopropane', 'class_level_name': 'ClassyFire_class', 'class_name': 'Organonitrogen compounds', 'source': 'hmdb', 'directIdClassHits': 1}, {'sourceId': 'hmdb:HMDB0000002', 'common_names': '1,3-Diaminopropane', 'class_level_name': 'ClassyFire_sub_class', 'class_name': 'Amines', 'source': 'hmdb', 'directIdClassHits': 1}, {'sourceId': 'hmdb:HMDB0000002', 'common_names': '1,3-Diaminopropane', 'class_level_name': 'ClassyFire_super_class', 'class_name': 'Organic nitrogen compounds', 'source': 'hmdb', 'directIdClassHits': 1}], 'function_call': ['RaMP::chemicalClassSurvey(c("hmdb:HMDB0000001", "hmdb:HMDB0000002"))\n'], 'numFoundIds': [2]}
# No pathway data found
#
# === Protein Pathway Analysis ===
#
# Protein pathways:
# {'data': [{'pathwayName': '11p11.2 copy number variation syndrome', 'pathwaySource': 'wiki', 'pathwayId': 'WP5348', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': '16p11.2 proximal deletion syndrome', 'pathwaySource': 'wiki', 'pathwayId': 'WP4949', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': '8q11.23 (RB1CC1) copy number variation', 'pathwaySource': 'wiki', 'pathwayId': 'WP5412', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'A network map of Macrophage-stimulating protein (MSP) signaling', 'pathwaySource': 'wiki', 'pathwayId': 'WP5353', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Activation of BH3-only proteins', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-114452', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Activation of NMDA receptors and postsynaptic events', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-442755', 'inputId': 'uniprot:P31323', 'commonName': 'PRKAR2B'}, {'pathwayName': 'Activation of NOXA and translocation to mitochondria', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-111448', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Activation of PUMA and translocation to mitochondria', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-139915', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'ADORA2B mediated anti-inflammatory cytokines production', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-9660821', 'inputId': 'uniprot:P31323', 'commonName': 'PRKAR2B'}, {'pathwayName': 'AMP-activated protein kinase signaling', 'pathwaySource': 'wiki', 'pathwayId': 'WP1403', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Amyotrophic lateral sclerosis (ALS)', 'pathwaySource': 'wiki', 'pathwayId': 'WP2447', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Anchoring of the basal body to the plasma membrane', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-5620912', 'inputId': 'uniprot:P31323', 'commonName': 'PRKAR2B'}, {'pathwayName': 'Androgen receptor network in prostate cancer', 'pathwaySource': 'wiki', 'pathwayId': 'WP2263', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Apoptosis', 'pathwaySource': 'wiki', 'pathwayId': 'WP254', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Apoptosis modulation and signaling', 'pathwaySource': 'wiki', 'pathwayId': 'WP1772', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Aquaporin-mediated transport', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-445717', 'inputId': 'uniprot:P31323', 'commonName': 'PRKAR2B'}, {'pathwayName': 'Association of TriC/CCT with target proteins during biosynthesis', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-390471', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'ATM signaling pathway', 'pathwaySource': 'wiki', 'pathwayId': 'WP2516', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'AURKA Activation by TPX2', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-8854518', 'inputId': 'uniprot:P31323', 'commonName': 'PRKAR2B'}, {'pathwayName': 'Autodegradation of the E3 ubiquitin ligase COP1', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-349425', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Autophagy in pancreatic ductal adenocarcinoma', 'pathwaySource': 'wiki', 'pathwayId': 'WP5331', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Bladder cancer', 'pathwaySource': 'wiki', 'pathwayId': 'WP2828', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Burn wound healing', 'pathwaySource': 'wiki', 'pathwayId': 'WP5055', 'inputId': 'uniprot:P04637', 'commonName': 'TP53'}, {'pathwayName': 'Ca-dependent events', 'pathwaySource': 'reactome', 'pathwayId': 'R-HSA-111996', 'inputId': 'uniprot:P31323', 'commonName': 'PRKAR2B'}, {'pathwayName': 'Calmodulin induced events', 'pathwaySource': 'reactome', ' ...
# No pathway data found
#
# === Combined Analysis ===
#
# Common reaction analytes:
# {'data': [{'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000001', 'input_common_names': '1-Methylhistidine', 'rxn_partner_common_name': 'CNDP1', 'rxn_partner_ids': 'hmdb:HMDBP00473,gene_symbol:CNDP1,uniprot:Q96KN2,uniprot:Q14D40,uniprot:Q17S05,uniprot:Q2TBG0,uniprot:Q6UWK2,uniprot:Q9BT98'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000001', 'input_common_names': '1-Methylhistidine', 'rxn_partner_common_name': 'PRMT3', 'rxn_partner_ids': 'hmdb:HMDBP00474,gene_symbol:PRMT3,uniprot:O60678,entrez:10196,ensembl:ENSG00000185238,uniprot:E9PRB4,uniprot:E9PLF6,uniprot:A0A0A0MSN7,uniprot:B4DUC7'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000002', 'input_common_names': '1,3-Diaminopropane', 'rxn_partner_common_name': 'SMS', 'rxn_partner_ids': 'hmdb:HMDBP00217,gene_symbol:SMS,uniprot:P52788,entrez:6611,ensembl:ENSG00000102172,uniprot:H7C2R7,uniprot:A6NHA7,uniprot:A6NI34,uniprot:B2R9M0,uniprot:O00544,uniprot:Q9UQS1'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000002', 'input_common_names': '1,3-Diaminopropane', 'rxn_partner_common_name': 'DHPS', 'rxn_partner_ids': 'hmdb:HMDBP00219,gene_symbol:DHPS,uniprot:P49366,entrez:1725,ensembl:ENSG00000095059,uniprot:A0A024R7E9,uniprot:M0QZT3,uniprot:A0A024R7D0,uniprot:M0R264,uniprot:M0QYZ7,uniprot:Q5J8M5,uniprot:M0R0J4,uniprot:M0R1T4,uniprot:M0QX43,uniprot:M0R0V2,uniprot:M0R1T2,uniprot:M0QXT2,uniprot:B4E3M2,uniprot:M0R253,uniprot:A8K688,uniprot:M0R1I5,uniprot:Q13184,uniprot:Q13276,uniprot:Q9UDG0'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000002', 'input_common_names': '1,3-Diaminopropane', 'rxn_partner_common_name': 'ABP1,AOC1', 'rxn_partner_ids': 'hmdb:HMDBP00390,gene_symbol:ABP1,uniprot:P19801,gene_symbol:AOC1,entrez:26,ensembl:ENSG00000002726,uniprot:C9J2J4,uniprot:C9J0G8,uniprot:C9J690,uniprot:Q16683,uniprot:Q16684,uniprot:Q56II4,uniprot:Q6GU42'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000002', 'input_common_names': '1,3-Diaminopropane', 'rxn_partner_common_name': 'AOC3', 'rxn_partner_ids': 'hmdb:HMDBP00393,gene_symbol:AOC3,uniprot:Q16853,entrez:8639,ensembl:ENSG00000131471,uniprot:K7EL47,uniprot:K7EIK5,uniprot:K7EQZ5,uniprot:B2RCI5,uniprot:K7ESB3,uniprot:L0L8N9,uniprot:Q45F94'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000002', 'input_common_names': '1,3-Diaminopropane', 'rxn_partner_common_name': 'AOC2', 'rxn_partner_ids': 'hmdb:HMDBP00394,gene_symbol:AOC2,uniprot:O75106,entrez:314,ensembl:ENSG00000131480,uniprot:A5PKW2,uniprot:O00120,uniprot:O75105,uniprot:Q4TTW5,uniprot:Q9UNY0'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000002', 'input_common_names': '1,3-Diaminopropane', 'rxn_partner_common_name': 'AMD1', 'rxn_partner_ids': 'hmdb:HMDBP00420,gene_symbol:AMD1,uniprot:P17707,entrez:262,ensembl:ENSG00000123505,uniprot:Q5VXN5,uniprot:F6R5I9,uniprot:B4DZ60,uniprot:A0A5F9ZHD5,uniprot:E1P5F7,uniprot:Q5VXN4,uniprot:Q5VXN6,uniprot:Q9BWK4'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000002', 'input_common_names': '1,3-Diaminopropane', 'rxn_partner_common_name': 'ODC1', 'rxn_partner_ids': 'hmdb:HMDBP01034,gene_symbol:ODC1,uniprot:P11926,entrez:4953,ensembl:ENSG00000115758,uniprot:C9JG30,uniprot:Q53TU3,uniprot:Q6LDS9'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000001', 'input_common_names': '1-Methylhistidine', 'rxn_partner_common_name': 'CARNS1', 'rxn_partner_ids': 'hmdb:HMDBP08844,gene_symbol:CARNS1,uniprot:A5YM72,entrez:57571,ensembl:ENSG00000172508,uniprot:A8K1M3,uniprot:B4DFC6,uniprot:E9PK38,uniprot:F5H427,uniprot:Q8N467,uniprot:Q9P2F3'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000001', 'input_common_names': '1-Methylhistidine', 'rxn_partner_common_name': 'HEMK1', 'rxn_partner_ids': 'hmdb:HMDBP11778,gene_symbol:HEMK1,uniprot:Q9Y5R4'}, {'query_relation': 'met2gene', 'input_analyte': 'hmdb:HMDB0000001', 'input_common_names': '1-Methylhistidine', 'rxn_partner_common_name': 'METTL2B', 'rxn_partner_ids': 'hmdb:HMDB ...
# Failed to get reactions after 3 attempts: Request failed: 500 Server Error: Internal Server Error for url: https://rampdb.nih.gov/api/reactions-from-analytes
# Failed to get reaction classes after 3 attempts: Request failed: 500 Server Error: Internal Server Error for url: https://rampdb.nih.gov/api/reaction-classes-from-analytes
#
# === Ontology Analysis ===
#
# Ontologies for metabolites:
# {'data': [{'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Saliva', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Feces', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Cytoplasm', 'HMDBOntologyType': 'Subcellular'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Urine', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Skeletal muscle', 'HMDBOntologyType': 'Tissue and substructures'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Blood', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Prostate', 'HMDBOntologyType': 'Organ and components'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Cerebrospinal fluid', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Pharmaceutical', 'HMDBOntologyType': 'Industrial application'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Endogenous', 'HMDBOntologyType': 'Source'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Diabetes mellitus type 2', 'HMDBOntologyType': 'Health condition'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Muscle', 'HMDBOntologyType': 'Tissue and substructures'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Obesity', 'HMDBOntologyType': 'Health condition'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Placenta', 'HMDBOntologyType': 'Tissue and substructures'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Pharmaceutical industry', 'HMDBOntologyType': 'Industrial application'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Kidney disease', 'HMDBOntologyType': 'Health condition'}, {'Metabolites': '1-Methylhistidine', 'sourceId': 'hmdb:HMDB0000001', 'IDtype': 'hmdb', 'Ontology': 'Metabolism and nutrition disorders', 'HMDBOntologyType': 'Health condition'}, {'Metabolites': '1,3-Diaminopropane', 'sourceId': 'hmdb:HMDB0000002', 'IDtype': 'hmdb', 'Ontology': 'Feces', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1,3-diaminopropane', 'sourceId': 'hmdb:HMDB0000002', 'IDtype': 'hmdb', 'Ontology': 'Feces', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1,3-Diaminopropane', 'sourceId': 'hmdb:HMDB0000002', 'IDtype': 'hmdb', 'Ontology': 'Urine', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1,3-diaminopropane', 'sourceId': 'hmdb:HMDB0000002', 'IDtype': 'hmdb', 'Ontology': 'Urine', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1,3-Diaminopropane', 'sourceId': 'hmdb:HMDB0000002', 'IDtype': 'hmdb', 'Ontology': 'Blood', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1,3-diaminopropane', 'sourceId': 'hmdb:HMDB0000002', 'IDtype': 'hmdb', 'Ontology': 'Blood', 'HMDBOntologyType': 'Biofluid and excreta'}, {'Metabolites': '1,3-Diaminopropane', 'sourceId': 'hmdb:HMDB0000002', 'IDtype': 'hmdb', 'Ontology': 'Endogenous', 'HMDBOntologyType': 'Source'}, {'Metabolites': '1,3-diaminopropane', 'sourceId': 'hmdb:HMDB0000002', 'IDtype': 'hmdb', 'Ontology': 'Endogenous', 'HMDBOntologyType': 'Source'}, {'Metabolites': '1,3-Diaminopropane', 'sourceId': 'hmdb:HMDB0000002', ' ...
# Failed to get metabolites from ontologies after 3 attempts: Request failed: 500 Server Error: Internal Server Error for url: https://rampdb.nih.gov/api/metabolites-from-ontologies
#
# === Enrichment Analysis ===
#
# Chemical enrichment results:
# {'data': {'ClassyFire_class': [{'category': 'ClassyFire_class', 'class_name': 'Organonitrogen compounds', 'met_hits': 1, 'pop_hits': 685, 'met_size': 2, 'pop_size': 145833, 'p-value': 0.0094, 'adjP_BH': 0.0187}, {'category': 'ClassyFire_class', 'class_name': 'Carboxylic acids and derivatives', 'met_hits': 1, 'pop_hits': 4270, 'met_size': 2, 'pop_size': 145833, 'p-value': 0.0577, 'adjP_BH': 0.0577}], 'ClassyFire_sub_class': [{'category': 'ClassyFire_sub_class', 'class_name': 'Amines', 'met_hits': 1, 'pop_hits': 375, 'met_size': 2, 'pop_size': 140755, 'p-value': 0.0053, 'adjP_BH': 0.0106}, {'category': 'ClassyFire_sub_class', 'class_name': 'Amino acids, peptides, and analogues', 'met_hits': 1, 'pop_hits': 3611, 'met_size': 2, 'pop_size': 140755, 'p-value': 0.0507, 'adjP_BH': 0.0507}], 'ClassyFire_super_class': [{'category': 'ClassyFire_super_class', 'class_name': 'Organic nitrogen compounds', 'met_hits': 1, 'pop_hits': 685, 'met_size': 2, 'pop_size': 145937, 'p-value': 0.0094, 'adjP_BH': 0.0187}, {'category': 'ClassyFire_super_class', 'class_name': 'Organic acids and derivatives', 'met_hits': 1, 'pop_hits': 5311, 'met_size': 2, 'pop_size': 145937, 'p-value': 0.0715, 'adjP_BH': 0.0715}], 'result_type': ['chemical_class_enrichment']}}
