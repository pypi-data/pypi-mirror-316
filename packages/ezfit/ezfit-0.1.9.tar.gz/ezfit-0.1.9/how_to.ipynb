# %%
import ezfit
from ezfit import SpectralPeak, Parameter
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import ezfit
#       2 from ezfit import SpectralPeak, Parameter
#       3 import pandas as pd
#
# File ~/projects/ezfit/ezfit/__init__.py:1
# ----> 1 from ezfit.fit import FitAccessor, Model, Parameter, MultiPeakModel, SpectralPeak
#       3 __all__ = ["Parameter", "Model", "FitAccessor", "MultiPeakModel", "SpectralPeak"]
#
# File ~/projects/ezfit/ezfit/fit.py:96
#      93         params= np.array([param.random() for param in self.params.values()])
#      94         return self.func(x, *params)
# ---> 96 @dataclass
#      97 class SpectralPeak:
#      98     """Data class for a peak function and its parameters."""
#      99     center: Parameter
#
# File /usr/lib/python3.12/dataclasses.py:1268, in dataclass(cls, init, repr, eq, order, unsafe_hash, frozen, match_args, kw_only, slots, weakref_slot)
# ...

# %%
def line(x, m, b):
    return m * x + b


test_data = pd.DataFrame(
    {
        "x": np.linspace(0, 10, 100),
        "y": np.linspace(0, 10, 100) + np.random.normal(0, .9, 100),
        "y_err": np.sqrt(np.linspace(0, 10, 100)) + 0.1,
    }
)
model, ax = test_data.fit(line, "x", "y", "y_err", m={"value":1, "min":.8, "max":1.2}, b={"value":0, "fixed":True})
print(model)
plt.show()
# Out:
# line:
# 𝜒2: None
# reduced 𝜒2: None
# m : (value=1 ± 0, bounds=(0.8, 1.2))
# b : (value=0.0000000000, fixed=True)
# line:
# 𝜒2: 47.66812288931745
# reduced 𝜒2: 0.4864094172379332
# m : (value=1.0005492097991913 ± 0.0468, bounds=(0.8, 1.2))
# b : (value=-0.0000000000, fixed=True)

# %%
center = Parameter(5)
amplitude = Parameter(1)
sigma = Parameter(1)
eta = Parameter(1)

peak = SpectralPeak(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 center = Parameter(5)
#       2 amplitude = Parameter(1)
#       3 sigma = Parameter(1)
#
# NameError: name 'Parameter' is not defined
