# %%
import logging

from sklearn.datasets import load_breast_cancer, load_diabetes
from sklearn.model_selection import train_test_split

from tabpfn_client import UserDataClient
from tabpfn_client.estimator import TabPFNClassifier, TabPFNRegressor

logging.basicConfig(level=logging.DEBUG)

# %%
import numpy as np
X = np.random.randn(100,100)
y = ((X @ np.random.randn(100)) > 0.).astype(int)

# %%
# set logging level to debug
# logging.basicConfig(level=logging.DEBUG)

use_server = True
# use_server = False

tabpfn = TabPFNClassifier(model="latest_tabpfn_hosted", n_estimators=1)
# print("checking estimator", check_estimator(tabpfn))
tabpfn.fit(X,y)
print("predicting_proba")
print(tabpfn.predict_proba(X))
# Out:
# DEBUG:httpcore.connection:connect_tcp.started host='tabpfn-server-wjedmz7r5a-ez.a.run.app' port=443 local_address=None timeout=30 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7ff464b98e50>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7ff4637dda40> server_hostname='tabpfn-server-wjedmz7r5a-ez.a.run.app' timeout=30
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7ff464b98730>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# ...
