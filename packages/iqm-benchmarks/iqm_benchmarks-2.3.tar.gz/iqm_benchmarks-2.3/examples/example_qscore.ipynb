# %%
# %load_ext autoreload
# %autoreload 2

# Optimization
from iqm.benchmarks.optimization.qscore import QScoreConfiguration

# General BenchmarkExperiment
from iqm.benchmarks.benchmark_experiment import BenchmarkExperiment

# %% [markdown]
# # Choose (or define) a backend

# %%
backend = "IQMFakeAdonis"
#backend = "IQMFakeApollo"
#backend = "garnet"
#backend = "deneb"

# %% [markdown]
# #### Set IQM Token if using Resonance.

# %%
# import os
# os.environ["IQM_TOKEN"] = ""

# %% [markdown]
# # -- Benchmark configuration --

# %% [markdown]
# ### Q-Score

# %%
EXAMPLE_QSCORE = QScoreConfiguration(
    num_instances = 100,
    num_qaoa_layers= 1,
    shots = 20_000,
    calset_id=None, # calibration set ID, default is None
    min_num_nodes =  2,
    max_num_nodes = 5,
    use_virtual_node = True,
    use_classically_optimized_angles = True,
    choose_qubits_routine = "custom",
    custom_qubits_array=[[2],
                    [2, 0],
                    [2, 0, 1],
                    [2, 0, 1, 3],
                    [2, 0, 1, 3, 4]],
    seed = 1
    )

# %% [markdown]
# # -- Running the experiment --

# %%
benchmark_list = [EXAMPLE_QSCORE]

# %%
EXAMPLE_EXPERIMENT = BenchmarkExperiment(backend, benchmark_list)
EXAMPLE_EXPERIMENT.run_experiment()
# Out:
# 2024-12-11 15:26:06,441 - iqm.benchmarks.logging_config - INFO -
# Now executing qscore
# 2024-12-11 15:26:06,454 - iqm.benchmarks.logging_config - INFO - Q-Score = 2 passed with:
# Approximation ratio (Beta): 0.6753; Avg MaxCut size: 0.5900
# 2024-12-11 15:26:09,682 - iqm.benchmarks.logging_config - INFO - Q-Score = 3 passed with:
# Approximation ratio (Beta): 0.5860; Avg MaxCut size: 1.2920
# 2024-12-11 15:26:23,111 - iqm.benchmarks.logging_config - INFO - Q-Score = 4 passed with:
# Approximation ratio (Beta): 0.4684; Avg MaxCut size: 2.1670
# 2024-12-11 15:26:45,951 - iqm.benchmarks.logging_config - INFO - Q-Score = 5 passed with:
# Approximation ratio (Beta): 0.3778; Avg MaxCut size: 3.2518
