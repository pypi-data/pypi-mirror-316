# %% [markdown]
# # LLMs

# %%
from esperanto import OpenAILanguageModel, XAILanguageModel, OpenRouterLanguageModel, AnthropicLanguageModel, OllamaLanguageModel, GoogleLanguageModel

messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What's the capital of France?"},
    ]


params = {
    "max_tokens": 850,
    "temperature": 1.0,
    "streaming": False,
    "top_p": 0.9,
    "structured": None
}

models = {
    "openrouter": {"class": OpenRouterLanguageModel, "model": "mistralai/mistral-large-2411"},
    "openai": {"class": OpenAILanguageModel, "model": "gpt-4o"},
    "xai": {"class": XAILanguageModel, "model": "grok-beta"},
    "anthropic": {"class": AnthropicLanguageModel, "model": "claude-3-opus-20240229"},
    "ollama": {"class": OllamaLanguageModel, "model": "gemma2"},
    "google": {"class": GoogleLanguageModel, "model": "gemini-2.0-flash-exp"},

}

# %% [markdown]
# ## Chat Completion

# %% [markdown]
# ### Synchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    result = llm.chat_complete(messages)
    print(result.choices[0].message.content)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# The capital of France is Paris. It's known for its art, culture, cuisine, and fashion, and it's home to iconic landmarks such as the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. If you have any other questions about France or anything else, feel free to ask!
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
#
# Paris is the largest city in France and is located in the north-central part of the country. It is situated on the River Seine and is a major global cultural, business, fashion, and tourist destination. Paris has a rich history dating back over 2,000 years and is known for its iconic landmarks such as the Eiffel Tower, the Louvre Museum, Notre-Dame Cathedral, and the Champs-Élysées.
#
# As the nation's capital, Paris is the seat of France's national government and is home to the official residences of the President (Élysée Palace) and the Prime Minister (Hôtel Matignon).
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**. 🇫🇷
#
#
# ==================================================
#
# Results for google:
# The capital of France is Paris.
#
#
# ==================================================

# %% [markdown]
# ### Asynchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    result = await llm.achat_complete(messages)
    print(result.choices[0].message.content)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# The capital of France is Paris. It's known for iconic attractions like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France.
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
#
# Paris is located in the north-central part of the country and is the most populous city in France. It is situated on the River Seine and is a major cultural, commercial, and political center in Europe. Paris is known for its iconic landmarks such as the Eiffel Tower, the Louvre Museum, Notre-Dame Cathedral, and the Champs-Élysées. The city has a rich history dating back to the 3rd century and has been the capital of France since the 12th century.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**.  🗼 🇫🇷
#
#
# ==================================================
#
# Results for google:
# The capital of France is Paris.
#
# ==================================================

# %% [markdown]
# ### JSON

# %%
import json

json_messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Please return the top 3 brazilian cities in JSON format"},
    ]


for name, config in models.items():
    llm = config["class"](model_name=config["model"], structured="json")
    print(f"Results for {llm.provider}:")
    result = llm.chat_complete(json_messages)
    try:
        json_data = json.loads(result.choices[0].message.content)
        print(json_data)
    except json.JSONDecodeError:
        print("Error decoding JSON")
    
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# Error decoding JSON
#
# ==================================================
#
# Results for openai:
# {'cities': [{'name': 'São Paulo', 'population': 12300000, 'state': 'São Paulo'}, {'name': 'Rio de Janeiro', 'population': 6748000, 'state': 'Rio de Janeiro'}, {'name': 'Brasília', 'population': 3055000, 'state': 'Distrito Federal'}]}
#
# ==================================================
#
# 2024-12-15 20:19:51 | esperanto | WARNING | Structured output not supported for X.AI.
# Results for xai:
# Error decoding JSON
#
# ==================================================
#
# Results for anthropic:
# 2024-12-15 20:19:55 | esperanto | WARNING | Structured output not supported for Anthropic.
# Error decoding JSON
#
# ==================================================
#
# Results for ollama:
# {'cities': ['São Paulo', 'Rio de Janeiro', 'Brasília']}
#
# ==================================================
#
# Results for google:
# {'top_cities': [{'rank': '1', 'city': 'São Paulo'}, {'rank': '2', 'city': 'Rio de Janeiro'}, {'rank': '3', 'city': 'Brasília'}]}
#
# ==================================================

# %% [markdown]
# ## Streaming

# %% [markdown]
# ### Synchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    result = llm.chat_complete(
        messages, stream=True
    )

    for chunk in result:
        print(chunk)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' Paris', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' It', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': "'", 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 's', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' known', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' for', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' icon', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 'ic', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' land', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 'marks', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' like', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' E', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 'iff', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 'el', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' Tower', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' Lou', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 'vre', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' Museum', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' and', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' Not', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 're', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': '-', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 'D', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 'ame', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' Cat', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 'hedral', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' It', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': "'", 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': 's', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' also', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' largest', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' city', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' in', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' and', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' an', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' important', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' cultural', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' commercial', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' and', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' political', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': ' center', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304804-OTB4AJVG2cYA58RJuk4O', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304804, object='chat.completion.chunk')
#
# ==================================================
#
# Results for openai:
# ChatCompletionChunk(id='chatcmpl-AesC60dWI5X64G6Z2HA8i4owgijyl', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304806, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesC60dWI5X64G6Z2HA8i4owgijyl', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304806, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesC60dWI5X64G6Z2HA8i4owgijyl', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304806, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesC60dWI5X64G6Z2HA8i4owgijyl', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304806, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesC60dWI5X64G6Z2HA8i4owgijyl', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304806, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesC60dWI5X64G6Z2HA8i4owgijyl', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304806, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesC60dWI5X64G6Z2HA8i4owgijyl', choices=[StreamChoice(index=0, delta={'content': ' Paris', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304806, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesC60dWI5X64G6Z2HA8i4owgijyl', choices=[StreamChoice(index=0, delta={'content': '.', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304806, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesC60dWI5X64G6Z2HA8i4owgijyl', choices=[StreamChoice(index=0, delta={'content': None, 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='gpt-4o-2024-08-06', created=1734304806, object='chat.completion.chunk')
#
# ==================================================
#
# Results for xai:
# ChatCompletionChunk(id='9761f06c-13cd-4de7-8788-ced74463a928', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304807, object='chat.completion.chunk')
# ChatCompletionChunk(id='9761f06c-13cd-4de7-8788-ced74463a928', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304807, object='chat.completion.chunk')
# ChatCompletionChunk(id='9761f06c-13cd-4de7-8788-ced74463a928', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304807, object='chat.completion.chunk')
# ChatCompletionChunk(id='9761f06c-13cd-4de7-8788-ced74463a928', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304807, object='chat.completion.chunk')
# ChatCompletionChunk(id='9761f06c-13cd-4de7-8788-ced74463a928', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304807, object='chat.completion.chunk')
# ChatCompletionChunk(id='9761f06c-13cd-4de7-8788-ced74463a928', choices=[StreamChoice(index=0, delta={'content': ' **', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304807, object='chat.completion.chunk')
# ChatCompletionChunk(id='9761f06c-13cd-4de7-8788-ced74463a928', choices=[StreamChoice(index=0, delta={'content': 'Paris', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304807, object='chat.completion.chunk')
# ChatCompletionChunk(id='9761f06c-13cd-4de7-8788-ced74463a928', choices=[StreamChoice(index=0, delta={'content': '**.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304807, object='chat.completion.chunk')
# ChatCompletionChunk(id='9761f06c-13cd-4de7-8788-ced74463a928', choices=[StreamChoice(index=0, delta={'content': None, 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='grok-beta', created=1734304807, object='chat.completion.chunk')
#
# ==================================================
#
# Results for anthropic:
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'The capital of France', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' is Paris.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='message_complete', choices=[StreamChoice(index=0, delta={'content': None, 'role': 'assistant'}, finish_reason='end_turn')], model='', created=0, object='chat.completion.chunk')
#
# ==================================================
#
# Results for ollama:
# ChatCompletionChunk(id='ad6b936d-6e13-4ae7-b468-13cc7d89f185', choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='524fb4b0-45c5-46cc-9468-4c605a2ac0b9', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='1e60490d-1f4e-4d03-9054-ac54214c0554', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='7b0075e4-9425-425d-a696-73b5c4a4f3a3', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='6659b5e2-e47f-4fe0-8339-1c6202cb73c3', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='a9bad227-daff-4c6b-ab77-d8929443dbcd', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' **', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='ba90a70b-6a2c-46d5-9fc2-2db1cc901020', choices=[StreamChoice(index=0, delta=DeltaMessage(content='Paris', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='60b02e9e-e697-4be4-ae99-918e75a134ef', choices=[StreamChoice(index=0, delta=DeltaMessage(content='**.', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='62f54c3e-6f89-4a53-9d6d-d214d2b1179e', choices=[StreamChoice(index=0, delta=DeltaMessage(content='  ', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='7a0716f4-1596-445b-8981-cbd8a2025f37', choices=[StreamChoice(index=0, delta=DeltaMessage(content='🗼', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='c9f3e185-bb8f-4023-9282-bee264a9ac49', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' ', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='942c378c-9051-4370-ae1e-7baf900598d7', choices=[StreamChoice(index=0, delta=DeltaMessage(content='🇫', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='ff8fbb36-e38e-42a1-93a0-d423d2f0a076', choices=[StreamChoice(index=0, delta=DeltaMessage(content='🇷', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='96665e6a-3db1-45d1-b910-3cad43593e4d', choices=[StreamChoice(index=0, delta=DeltaMessage(content='  ', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='2de2bf53-e318-45c8-b4cd-9a09433a9d7d', choices=[StreamChoice(index=0, delta=DeltaMessage(content='\n', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304808, object='chat.completion.chunk')
# ChatCompletionChunk(id='c60563ae-59f2-46c2-a963-de7061b740e9', choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')], model='gemma2', created=1734304808, object='chat.completion.chunk')
#
# ==================================================
#
# Results for google:
# ChatCompletionChunk(id='google-chunk-842312983484731355', choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemini-2.0-flash-exp', created=1734304809, object='chat.completion.chunk')
# ChatCompletionChunk(id='google-chunk-842312983484731355', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital of France is Paris.\n', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemini-2.0-flash-exp', created=1734304809, object='chat.completion.chunk')
#
# ==================================================

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    result = await llm.achat_complete(
        messages, stream=True
    )

    async for chunk in result:
        print(chunk)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' Paris', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' It', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': "'", 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 's', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' known', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' for', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' icon', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 'ic', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' land', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 'marks', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' like', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' E', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 'iff', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 'el', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' Tower', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' Lou', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 'vre', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' Museum', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' and', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' Not', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 're', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': '-', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 'D', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 'ame', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' Cat', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 'hedral', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' It', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': "'", 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': 's', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' also', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' the', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' largest', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' city', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' in', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
# ChatCompletionChunk(id='gen-1734304810-DAoWu58AEwWG2lP0gPn6', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='mistralai/mistral-large-2411', created=1734304810, object='chat.completion.chunk')
#
# ==================================================
#
# Results for openai:
# ChatCompletionChunk(id='chatcmpl-AesCC0tBNTPQpPmUqXxABzsnv9Ade', choices=[StreamChoice(index=0, delta={'content': '', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304812, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesCC0tBNTPQpPmUqXxABzsnv9Ade', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304812, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesCC0tBNTPQpPmUqXxABzsnv9Ade', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304812, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesCC0tBNTPQpPmUqXxABzsnv9Ade', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304812, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesCC0tBNTPQpPmUqXxABzsnv9Ade', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304812, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesCC0tBNTPQpPmUqXxABzsnv9Ade', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304812, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesCC0tBNTPQpPmUqXxABzsnv9Ade', choices=[StreamChoice(index=0, delta={'content': ' Paris', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304812, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesCC0tBNTPQpPmUqXxABzsnv9Ade', choices=[StreamChoice(index=0, delta={'content': '.', 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='gpt-4o-2024-08-06', created=1734304812, object='chat.completion.chunk')
# ChatCompletionChunk(id='chatcmpl-AesCC0tBNTPQpPmUqXxABzsnv9Ade', choices=[StreamChoice(index=0, delta={'content': None, 'role': None, 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='gpt-4o-2024-08-06', created=1734304812, object='chat.completion.chunk')
#
# ==================================================
#
# Results for xai:
# ChatCompletionChunk(id='a42fb5f3-098b-4b87-80bd-a48aa62773ab', choices=[StreamChoice(index=0, delta={'content': 'The', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304814, object='chat.completion.chunk')
# ChatCompletionChunk(id='a42fb5f3-098b-4b87-80bd-a48aa62773ab', choices=[StreamChoice(index=0, delta={'content': ' capital', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304814, object='chat.completion.chunk')
# ChatCompletionChunk(id='a42fb5f3-098b-4b87-80bd-a48aa62773ab', choices=[StreamChoice(index=0, delta={'content': ' of', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304814, object='chat.completion.chunk')
# ChatCompletionChunk(id='a42fb5f3-098b-4b87-80bd-a48aa62773ab', choices=[StreamChoice(index=0, delta={'content': ' France', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304814, object='chat.completion.chunk')
# ChatCompletionChunk(id='a42fb5f3-098b-4b87-80bd-a48aa62773ab', choices=[StreamChoice(index=0, delta={'content': ' is', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304814, object='chat.completion.chunk')
# ChatCompletionChunk(id='a42fb5f3-098b-4b87-80bd-a48aa62773ab', choices=[StreamChoice(index=0, delta={'content': ' **', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304814, object='chat.completion.chunk')
# ChatCompletionChunk(id='a42fb5f3-098b-4b87-80bd-a48aa62773ab', choices=[StreamChoice(index=0, delta={'content': 'Paris', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304814, object='chat.completion.chunk')
# ChatCompletionChunk(id='a42fb5f3-098b-4b87-80bd-a48aa62773ab', choices=[StreamChoice(index=0, delta={'content': '**.', 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason=None)], model='grok-beta', created=1734304814, object='chat.completion.chunk')
# ChatCompletionChunk(id='a42fb5f3-098b-4b87-80bd-a48aa62773ab', choices=[StreamChoice(index=0, delta={'content': None, 'role': 'assistant', 'function_call': None, 'tool_calls': None}, finish_reason='stop')], model='grok-beta', created=1734304814, object='chat.completion.chunk')
#
# ==================================================
#
# Results for anthropic:
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'The capital of France', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' is Paris.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '\n\nParis', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' is locate', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd in the north', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '-', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'central part', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' of the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' country an', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd is the most', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' populous city in France', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '. It is situate', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd on the River', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Seine and is a', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' major global center for', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' art', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', fashion', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', gast', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'ronomy, an', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd culture.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Paris is also', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' home to many', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' famous', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' landmarks,', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' such as the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Eiffel Tower', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Lo', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'uvre Museum, Notre', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '-', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'Dame Cathedral, an', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' Ch', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'amps-Él', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'ysées.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '\n\nThe city', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' has', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' been', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' the capital of France', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' since the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' 12', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'th century an', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': 'd has played a significant', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' role in the', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' country', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': "'s history", 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ',', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ' politics', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': ', and economy', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='0', choices=[StreamChoice(index=0, delta={'content': '.', 'role': 'assistant'}, finish_reason=None)], model='', created=0, object='chat.completion.chunk')
# ChatCompletionChunk(id='message_complete', choices=[StreamChoice(index=0, delta={'content': None, 'role': 'assistant'}, finish_reason='end_turn')], model='', created=0, object='chat.completion.chunk')
#
# ==================================================
#
# Results for ollama:
# ChatCompletionChunk(id='46101752-3701-41d7-a70c-b803f7ce7dc0', choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='bb570449-f7ae-470b-9755-62ed1bc78284', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='26653e38-b9e1-4c26-81b1-f742402ac41d', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' of', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='a1a35453-b773-4a71-93a0-fe661a76a243', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' France', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='3c4946b1-0c5c-4d84-8cc2-f4468bc1ebd7', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' is', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='049530e3-2db7-4963-9d1b-f78628091d0c', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' Paris', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='999fd16f-fd7e-4cf6-b9f1-6224a6d8a9ef', choices=[StreamChoice(index=0, delta=DeltaMessage(content='.', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='7e65bcfb-0017-44a8-a297-18854953ee81', choices=[StreamChoice(index=0, delta=DeltaMessage(content='  ', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='b161db64-ba75-4592-8267-944050582bee', choices=[StreamChoice(index=0, delta=DeltaMessage(content='🗼', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='4f05bd93-e251-4756-a1e4-3a5bc825fc89', choices=[StreamChoice(index=0, delta=DeltaMessage(content='  ', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='0219b2b0-986a-49d1-aab8-3c9fedf81a69', choices=[StreamChoice(index=0, delta=DeltaMessage(content='\n', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemma2', created=1734304819, object='chat.completion.chunk')
# ChatCompletionChunk(id='d07577cd-f432-4353-a962-6d93a78f288c', choices=[StreamChoice(index=0, delta=DeltaMessage(content='', role='assistant', function_call=None, tool_calls=None), finish_reason='stop')], model='gemma2', created=1734304819, object='chat.completion.chunk')
#
# ==================================================
#
# Results for google:
# ChatCompletionChunk(id='google-chunk-842312983484731355', choices=[StreamChoice(index=0, delta=DeltaMessage(content='The', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemini-2.0-flash-exp', created=1734304820, object='chat.completion.chunk')
# ChatCompletionChunk(id='google-chunk-842312983484731355', choices=[StreamChoice(index=0, delta=DeltaMessage(content=' capital of France is Paris.\n', role='assistant', function_call=None, tool_calls=None), finish_reason=None)], model='gemini-2.0-flash-exp', created=1734304820, object='chat.completion.chunk')
#
# ==================================================

# %% [markdown]
# ## LangChain

# %% [markdown]
# ### Synchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    model = llm.to_langchain()
    response = model.invoke(messages)
    print(response.content)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734304820.907155 11872168 fork_posix.cc:75] Other threads are currently calling into gRPC, skipping fork() handlers
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France.
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**.  🇫🇷
#
#
# ==================================================
#
# Results for google:
# The capital of France is **Paris**.
#
#
# ==================================================

# %% [markdown]
# ### Asynchronous

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"])
    print(f"Results for {llm.provider}:")
    model = llm.to_langchain()
    response = await model.ainvoke(messages)
    print(response.content)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# The capital of France is Paris. It's known for iconic landmarks like the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral. It's also the largest city in France.
#
# ==================================================
#
# Results for openai:
# The capital of France is Paris.
#
# ==================================================
#
# Results for xai:
# The capital of France is **Paris**.
#
# ==================================================
#
# Results for anthropic:
# The capital of France is Paris.
#
# ==================================================
#
# Results for ollama:
# The capital of France is **Paris**.  🇫🇷 🗼 🥖
#
#
# ==================================================
#
# Results for google:
# The capital of France is **Paris**.
#
#
# ==================================================

# %% [markdown]
# ### Streaming

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"], streaming=True)
    print(f"Results for {llm.provider}:")
    model = llm.to_langchain()
    response = model.stream(messages)
    for chunk in response:
        print(chunk)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# content='' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='The' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' capital' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' of' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' France' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' is' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' Paris' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='.' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' It' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content="'" additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='s' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' known' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' for' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' icon' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='ic' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' land' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='marks' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' like' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' the' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' E' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='iff' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='el' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' Tower' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=',' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' the' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' Lou' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='vre' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' Museum' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=',' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' and' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' Not' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='re' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='-' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='D' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='ame' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' Cat' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='hedral' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='.' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' It' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content="'" additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='s' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' also' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' the' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' largest' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' city' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' in' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content=' France' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='.' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'mistralai/mistral-large-2411'} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560'
# content='' additional_kwargs={} response_metadata={} id='run-4d84ef87-3418-41a9-92f6-a0eff31d6560' usage_metadata={'input_tokens': 19, 'output_tokens': 47, 'total_tokens': 66, 'input_token_details': {}, 'output_token_details': {}}
#
# ==================================================
#
# Results for openai:
# content='' additional_kwargs={} response_metadata={} id='run-5523a8cd-d48f-41fc-a36f-98ed499ba879'
# content='The' additional_kwargs={} response_metadata={} id='run-5523a8cd-d48f-41fc-a36f-98ed499ba879'
# content=' capital' additional_kwargs={} response_metadata={} id='run-5523a8cd-d48f-41fc-a36f-98ed499ba879'
# content=' of' additional_kwargs={} response_metadata={} id='run-5523a8cd-d48f-41fc-a36f-98ed499ba879'
# content=' France' additional_kwargs={} response_metadata={} id='run-5523a8cd-d48f-41fc-a36f-98ed499ba879'
# content=' is' additional_kwargs={} response_metadata={} id='run-5523a8cd-d48f-41fc-a36f-98ed499ba879'
# content=' Paris' additional_kwargs={} response_metadata={} id='run-5523a8cd-d48f-41fc-a36f-98ed499ba879'
# content='.' additional_kwargs={} response_metadata={} id='run-5523a8cd-d48f-41fc-a36f-98ed499ba879'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9faba9f038'} id='run-5523a8cd-d48f-41fc-a36f-98ed499ba879'
#
# ==================================================
#
# Results for xai:
# content='The' additional_kwargs={} response_metadata={} id='run-cb3938b9-eb02-4d0b-bd66-87ff96e9c008' usage_metadata={'input_tokens': 23, 'output_tokens': 1, 'total_tokens': 24, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' capital' additional_kwargs={} response_metadata={} id='run-cb3938b9-eb02-4d0b-bd66-87ff96e9c008' usage_metadata={'input_tokens': 23, 'output_tokens': 2, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' of' additional_kwargs={} response_metadata={} id='run-cb3938b9-eb02-4d0b-bd66-87ff96e9c008' usage_metadata={'input_tokens': 23, 'output_tokens': 3, 'total_tokens': 26, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' France' additional_kwargs={} response_metadata={} id='run-cb3938b9-eb02-4d0b-bd66-87ff96e9c008' usage_metadata={'input_tokens': 23, 'output_tokens': 4, 'total_tokens': 27, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' is' additional_kwargs={} response_metadata={} id='run-cb3938b9-eb02-4d0b-bd66-87ff96e9c008' usage_metadata={'input_tokens': 23, 'output_tokens': 5, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' **' additional_kwargs={} response_metadata={} id='run-cb3938b9-eb02-4d0b-bd66-87ff96e9c008' usage_metadata={'input_tokens': 23, 'output_tokens': 6, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='Paris' additional_kwargs={} response_metadata={} id='run-cb3938b9-eb02-4d0b-bd66-87ff96e9c008' usage_metadata={'input_tokens': 23, 'output_tokens': 7, 'total_tokens': 30, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='**.' additional_kwargs={} response_metadata={} id='run-cb3938b9-eb02-4d0b-bd66-87ff96e9c008' usage_metadata={'input_tokens': 23, 'output_tokens': 8, 'total_tokens': 31, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'grok-beta', 'system_fingerprint': 'fp_a019526223'} id='run-cb3938b9-eb02-4d0b-bd66-87ff96e9c008' usage_metadata={'input_tokens': 23, 'output_tokens': 9, 'total_tokens': 32, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
#
# ==================================================
#
# Results for anthropic:
# content='' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442' usage_metadata={'input_tokens': 20, 'output_tokens': 3, 'total_tokens': 23, 'input_token_details': {}}
# content='The capital of' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' France is Paris.' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content='\n\nParis is locate' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content='d in the north' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content='-central part of the' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' country and is the most' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' populous city in France' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content='. It is situate' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content='d on the River Seine and is a' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' major cultural, commercial' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=', and political center' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' in Europe. Paris is' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' known for its iconic' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' landmarks such as the' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' Eiffel' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' Tower, the Louvre Museum' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=', Notre-Dame Cathedral,' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' and the Champs-' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content='Élysées.' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' The city is' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' also famous' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=' for its cuisine' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content=', fashion, an' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content='d art scene.' additional_kwargs={} response_metadata={} id='run-f6a971fd-5b30-433b-9984-a41615379442'
# content='' additional_kwargs={} response_metadata={'stop_reason': 'end_turn', 'stop_sequence': None} id='run-f6a971fd-5b30-433b-9984-a41615379442' usage_metadata={'input_tokens': 0, 'output_tokens': 106, 'total_tokens': 106, 'input_token_details': {}}
#
# ==================================================
#
# Results for ollama:
# content='The' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content=' capital' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content=' of' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content=' France' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content=' is' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content=' **' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content='Paris' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content='**.' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content=' ' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content='🗼' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content='  ' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content='😊' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content='  ' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content='\n' additional_kwargs={} response_metadata={} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977'
# content='' additional_kwargs={} response_metadata={'model': 'gemma2', 'created_at': '2024-12-15T23:20:42.322764693Z', 'done': True, 'done_reason': 'stop', 'total_duration': 185613826, 'load_duration': 24759638, 'prompt_eval_count': 23, 'prompt_eval_duration': 7000000, 'eval_count': 15, 'eval_duration': 152000000, 'message': Message(role='assistant', content='', images=None, tool_calls=None)} id='run-be8d0c6a-b32c-4092-a229-fa5d8ea98977' usage_metadata={'input_tokens': 23, 'output_tokens': 15, 'total_tokens': 38}
#
# ==================================================
#
# Results for google:
# content='The' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-96ff4f9f-65f6-47e5-acfd-47cc48c71d6b' usage_metadata={'input_tokens': 15, 'output_tokens': 0, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}}
# content=' capital of France is **Paris**.\n' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-96ff4f9f-65f6-47e5-acfd-47cc48c71d6b' usage_metadata={'input_tokens': 0, 'output_tokens': 9, 'total_tokens': 9, 'input_token_details': {'cache_read': 0}}
#
# ==================================================

# %% [markdown]
# ### Asynchronous Streaming

# %%
for name, config in models.items():
    llm = config["class"](model_name=config["model"], streaming=True)
    print(f"Results for {llm.provider}:")
    model = llm.to_langchain()
    response = model.astream(messages)
    async for chunk in response:
        print(chunk)
    print("\n" + "="*50 + "\n")
# Out:
# Results for openrouter:
# content='' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content='The' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content=' capital of France is' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content=' Paris. It' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content="'s known" additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content=' for icon' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content='ic land' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content='marks like the E' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content='iffel Tower,' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content=' the' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content=' Louvre Museum,' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content=' and Not' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content='re-Dame' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content=' Cathedral. It' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content="'s also the" additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content=' largest' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content=' city in France' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content='.' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'mistralai/mistral-large-2411'} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037'
# content='' additional_kwargs={} response_metadata={} id='run-452ae1ce-8d41-4175-9afc-0e74b2cae037' usage_metadata={'input_tokens': 19, 'output_tokens': 47, 'total_tokens': 66, 'input_token_details': {}, 'output_token_details': {}}
#
# ==================================================
#
# Results for openai:
# content='' additional_kwargs={} response_metadata={} id='run-f59ed9b1-c410-4ba5-8b13-8c079dba64a9'
# content='The' additional_kwargs={} response_metadata={} id='run-f59ed9b1-c410-4ba5-8b13-8c079dba64a9'
# content=' capital' additional_kwargs={} response_metadata={} id='run-f59ed9b1-c410-4ba5-8b13-8c079dba64a9'
# content=' of' additional_kwargs={} response_metadata={} id='run-f59ed9b1-c410-4ba5-8b13-8c079dba64a9'
# content=' France' additional_kwargs={} response_metadata={} id='run-f59ed9b1-c410-4ba5-8b13-8c079dba64a9'
# content=' is' additional_kwargs={} response_metadata={} id='run-f59ed9b1-c410-4ba5-8b13-8c079dba64a9'
# content=' Paris' additional_kwargs={} response_metadata={} id='run-f59ed9b1-c410-4ba5-8b13-8c079dba64a9'
# content='.' additional_kwargs={} response_metadata={} id='run-f59ed9b1-c410-4ba5-8b13-8c079dba64a9'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9faba9f038'} id='run-f59ed9b1-c410-4ba5-8b13-8c079dba64a9'
#
# ==================================================
#
# Results for xai:
# content='The' additional_kwargs={} response_metadata={} id='run-0ded8c4b-890b-4e11-8c4b-0831e837fed2' usage_metadata={'input_tokens': 23, 'output_tokens': 1, 'total_tokens': 24, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' capital' additional_kwargs={} response_metadata={} id='run-0ded8c4b-890b-4e11-8c4b-0831e837fed2' usage_metadata={'input_tokens': 23, 'output_tokens': 2, 'total_tokens': 25, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' of' additional_kwargs={} response_metadata={} id='run-0ded8c4b-890b-4e11-8c4b-0831e837fed2' usage_metadata={'input_tokens': 23, 'output_tokens': 3, 'total_tokens': 26, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' France' additional_kwargs={} response_metadata={} id='run-0ded8c4b-890b-4e11-8c4b-0831e837fed2' usage_metadata={'input_tokens': 23, 'output_tokens': 4, 'total_tokens': 27, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' is' additional_kwargs={} response_metadata={} id='run-0ded8c4b-890b-4e11-8c4b-0831e837fed2' usage_metadata={'input_tokens': 23, 'output_tokens': 5, 'total_tokens': 28, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content=' **' additional_kwargs={} response_metadata={} id='run-0ded8c4b-890b-4e11-8c4b-0831e837fed2' usage_metadata={'input_tokens': 23, 'output_tokens': 6, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='Paris' additional_kwargs={} response_metadata={} id='run-0ded8c4b-890b-4e11-8c4b-0831e837fed2' usage_metadata={'input_tokens': 23, 'output_tokens': 7, 'total_tokens': 30, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='**.' additional_kwargs={} response_metadata={} id='run-0ded8c4b-890b-4e11-8c4b-0831e837fed2' usage_metadata={'input_tokens': 23, 'output_tokens': 8, 'total_tokens': 31, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'grok-beta', 'system_fingerprint': 'fp_a019526223'} id='run-0ded8c4b-890b-4e11-8c4b-0831e837fed2' usage_metadata={'input_tokens': 23, 'output_tokens': 9, 'total_tokens': 32, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {}}
#
# ==================================================
#
# Results for anthropic:
# content='' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef' usage_metadata={'input_tokens': 20, 'output_tokens': 4, 'total_tokens': 24, 'input_token_details': {}}
# content='The capital of France' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' is Paris.' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content='\n\nParis is the largest city' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' in France and is' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' located in the north' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content='-central part of the' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' country. It is' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' situate' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content='d on the River' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' Seine and is known' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' for its iconic' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' landmarks such' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' as the E' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content='iffel Tower,' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' the' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' Louvre Museum,' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' and the Cathedral' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' of Notre-Dame' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content='. Paris has been' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' the capital of France' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' since the' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' 12' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content='th century an' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content='d is also' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' the country' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content="'s major" additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' cultural, commercial' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=', and industrial' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' center.' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' The city is' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' renowned for its art' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=', fashion, cuisine' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=', and architecture,' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' making it one' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content=' of the worl' additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content="d's most popular tourist destinations." additional_kwargs={} response_metadata={} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef'
# content='' additional_kwargs={} response_metadata={'stop_reason': 'end_turn', 'stop_sequence': None} id='run-c5a5c37d-4ff6-41f7-9aa5-4be58f21d7ef' usage_metadata={'input_tokens': 0, 'output_tokens': 123, 'total_tokens': 123, 'input_token_details': {}}
#
# ==================================================
#
# Results for ollama:
# content='The' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content=' capital' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content=' of' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content=' France' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content=' is' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content=' **' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content='Paris' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content='**.' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content=' ' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content='🇫' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content='🇷' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content='  ' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content='😊' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content='  ' additional_kwargs={} response_metadata={} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8'
# content='' additional_kwargs={} response_metadata={'model': 'gemma2', 'created_at': '2024-12-15T23:20:52.066568582Z', 'done': True, 'done_reason': 'stop', 'total_duration': 185943097, 'load_duration': 27358497, 'prompt_eval_count': 23, 'prompt_eval_duration': 6000000, 'eval_count': 15, 'eval_duration': 151000000, 'message': Message(role='assistant', content='', images=None, tool_calls=None)} id='run-5b94a1d3-a33a-4e42-b3ef-46522f948af8' usage_metadata={'input_tokens': 23, 'output_tokens': 15, 'total_tokens': 38}
#
# ==================================================
#
# Results for google:
# content='The' additional_kwargs={} response_metadata={'safety_ratings': []} id='run-76b502f3-d0b9-4a4a-a4ce-8a5f03d1b1e5' usage_metadata={'input_tokens': 15, 'output_tokens': 0, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}}
# content=' capital of France is **Paris**.\n' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-76b502f3-d0b9-4a4a-a4ce-8a5f03d1b1e5' usage_metadata={'input_tokens': 0, 'output_tokens': 9, 'total_tokens': 9, 'input_token_details': {'cache_read': 0}}
#
# ==================================================
